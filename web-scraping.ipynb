# %%
import requests
from bs4 import BeautifulSoup
import certifi

url = "https://kbtu.edu.kz/ru/"

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

response = requests.get(url, headers=headers, verify=False)

print(response)
soup = BeautifulSoup(response.text, "html.parser")

# Find elements
title = soup.find("h1").text
links = [a["href"] for a in soup.find_all("a", href=True)]
all_paragraphs = [p.text for p in soup.find_all("p")]

print(title)
# Out:
# <Response [200]>
# События
# /Users/nurma/vscode_projects/Uni-Agent/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'kbtu.edu.kz'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ru-ru" dir="ltr">
#
# <head>
#     <meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<meta name="description" content="KBTU - Лучший Технический университет Казахстана - образование на английском языке в Алматы - диплом международного уровня - техническое образование в Алматы - Тел. ☎ +7( 727) 357 42 51">
# 	<meta name="generator" content="Joomla! - Open Source Content Management">
# 	<title>Казахстанско-Британский технический университет | КБТУ</title>
# 	<link href="/ru/?format=feed&amp;type=rss" rel="alternate" type="application/rss+xml" title="Казахстанско-Британский технический университет | КБТУ">
# 	<link href="/ru/?format=feed&amp;type=atom" rel="alternate" type="application/atom+xml" title="Казахстанско-Британский технический университет | КБТУ">
# 	<link href="https://kbtu.edu.kz/kz/" rel="alternate" hreflang="kz-KZ">
# 	<link href="https://kbtu.edu.kz/ru/" rel="alternate" hreflang="ru-RU">
# 	<link href="https://kbtu.edu.kz/en/" rel="alternate" hreflang="en-GB">
# 	<link href="/media/system/images/favicon.png" rel="shortcut icon" type="image/png">
#
# 	<link href="//fonts.googleapis.com/css?family=Open+Sans:300,300italic,regular,italic,600,600italic,700,700italic,800,800italic&amp;amp;subset=cyrillic-ext,latin&amp;display=swap" media="all" rel="stylesheet" as="style" onload="this.rel='stylesheet'">
#     <link href="/media/system/css/joomla-fontawesome.min.css?c89eb5" rel="lazy-stylesheet"><noscript><link href="/media/system/css/joomla-fontawesome.min.css?c89eb5" rel="stylesheet"></noscript>
# 	<link href="https://fonts.googleapis.com/css2?family=Fira+Sans:wght@100;300;400;700&amp;display=swap" rel="lazy-stylesheet" crossorigin="anonymous"><noscript><link href="https://fonts.googleapis.com/css2?family=Fira+Sans:wght@100;300;400;700&amp;display=swap" rel="stylesheet"></noscript>
# 	<link href="/media/templates/site/cassiopeia/css/template.css?c89eb5" rel="stylesheet">
# 	<link href="/media/templates/site/cassiopeia/css/global/colors_standard.min.css?c89eb5" rel="stylesheet">
# 	<link href="/media/templates/site/cassiopeia/css/bootstrap.min.css?c89eb5" rel="stylesheet">
# 	<link href="/media/templates/site/cassiopeia/css/personal.css?c89eb5" rel="stylesheet">
# 	<link href="/media/mod_articles/css/mod-articles.min.css?c89eb5" rel="stylesheet">
# 	<link href="/media/mod_languages/css/template.min.css?c89eb5" rel="stylesheet">
# 	<link href="/media/templates/site/cassiopeia/css/vendor/joomla-custom-elements/joomla-alert.min.css?0.2.0" rel="stylesheet">
# 	<link href="/media/com_sliderck/assets/swiper.css?ver=2.4.4" rel="stylesheet">
# 	<style>:root {
# 		--hue: 214;
# 		--template-bg-light: #f0f4fb;
# 		--template-text-dark: #495057;
# 		--template-text-light: #ffffff;
# 		--template-link-color: var(--link-color);
# 		--template-special-color: #001B4C;
# 		--cassiopeia-font-family-body: "Fira Sans", sans-serif;
# 			--cassiopeia-font-family-headings: "Fira Sans", sans-serif;
# 			--cassiopeia-font-weight-normal: 400;
# 			--cassiopeia-font-weight-headings: 700;
# 	}</style>
# 	<style>#sliderck315 .swiper-img-cont { background-size: cover; }</style>
# 	<style>#sliderck314 .swiper-img-cont { background-size: cover; }</style>
# 	<style>#sliderck311 { height: 50px; }#sliderck311 .swiper-slide .swiper-img { height: 100% }#sliderck311 .swiper-img-cont { background-size: auto 100% }</style>
# 	<style>#sliderck316 { height: 50px; }#sliderck316 .swiper-slide .swiper-img { height: 100% }#sliderck316 .swiper-img-cont { background-size: auto 100% }</style>
#
#     <script src="/media/vendor/jquery/js/jquery.min.js?3.7.1"></script>
# 	<script src="/media/legacy/js/jquery-noconflict.min.js?504da4"></script>
# 	<script src="/media/templates/site/cassiopeia/js/bootstrap.bundle.min.js?c89eb5"></script>
# 	<script src="/media/templates/site/cassiopeia/js/personal.js?c89eb5"></script>
# 	<script src="/media/mod_menu/js/menu.min.js?c89eb5" type="module"></script>
# 	<script type="application/json" class="joomla-script-options new">{"joomla.jtext":{"MOD_FINDER_SEARCH_VALUE":"Введите текст...","ERROR":"Ошибка","MESSAGE":"Сообщение","NOTICE":"Внимание","WARNING":"Предупреждение","JCLOSE":"Закрыть","JOK":"Ок","JOPEN":"Открыть"},"system.paths":{"root":"","rootFull":"https://kbtu.edu.kz/","base":"","baseFull":"https://kbtu.edu.kz/"},"csrf.token":"053e1d4632883d2054a7239848741cdb"}</script>
# 	<script src="/media/system/js/core.min.js?2cb912"></script>
# 	<script src="/media/templates/site/cassiopeia/js/template.min.js?c89eb5" type="module"></script>
# 	<script src="/media/com_finder/js/finder.min.js?5729ed" type="module"></script>
# 	<script src="/media/system/js/messages.min.js?9a4811" type="module"></script>
# 	<script src="/media/com_sliderck/assets/swiper.min.js?ver=2.4.4"></script>
# 	<script>jQuery(document).ready(function(){
# 	var sliderck315 = new Swiper('#sliderck315', {
# 		pagination: '.swiper-pagination',
# 		paginationClickable: true,
# 		setWrapperSize: true, // nécessaire pour garder les images centrées lors de la réduction de la fenêtre
# 		slidesPerView: '1',
# 		slidesPerGroup: 1,
# 		slidesPerColumn: 1,
# 		spaceBetween: 10,
# 		centeredSlides: false,
# 		initialSlide: 0,
# 		freeMode: 0,
# 		speed: 3000,
# 		autoplay: 8000,
# 		autoplayDisableOnInteraction: true,
# 		autoplayStopOnLast: 1,
# 		autoplayPauseOnOver: false,
# 		effect: 'slide',
# 		fade: {crossFade: true},
# 		loop: true,
# 		loopedSlides: 8,
# 		keyboardControl: 0,
# 		mousewheelControl: 0,
# 		a11y: true,
# 		paginationType: 'bullets', // 'bullets' or 'progress' or 'fraction' or 'custom'
# 		breakpoints: {
# 360: {
# 			slidesPerView: 1,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 1
# 		},
# 480: {
# 			slidesPerView: 1,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 1
# 		},
# 640: {
# 			slidesPerView: 3,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 30
# 		}},
#
# 		// direction: 'horizontal',
# 		// autoHeight: true, //enable auto height to use more with content in slides. Not for images
#
# 	});
#
# });
# </script>
# 	<script>jQuery(document).ready(function(){
# 	var sliderck314 = new Swiper('#sliderck314', {
# 		pagination: '.swiper-pagination',
# 		paginationClickable: true,
# 		setWrapperSize: true, // nécessaire pour garder les images centrées lors de la réduction de la fenêtre
# 		slidesPerView: '3',
# 		slidesPerGroup: 1,
# 		slidesPerColumn: 1,
# 		spaceBetween: 1,
# 		centeredSlides: false,
# 		initialSlide: 0,
# 		freeMode: 0,
# 		speed: 3000,
# 		autoplay: 1000,
# 		autoplayDisableOnInteraction: true,
# 		autoplayStopOnLast: 1,
# 		autoplayPauseOnOver: false,
# 		effect: 'slide',
# 		fade: {crossFade: true},
# 		loop: true,
# 		loopedSlides: 8,
# 		keyboardControl: 0,
# 		mousewheelControl: 0,
# 		a11y: true,
# 		paginationType: 'bullets', // 'bullets' or 'progress' or 'fraction' or 'custom'
# 		breakpoints: {
# 360: {
# 			slidesPerView: 1,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 1
# 		},
# 480: {
# 			slidesPerView: 1,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 1
# 		},
# 640: {
# 			slidesPerView: 3,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 30
# 		}},
#
# 		// direction: 'horizontal',
# 		// autoHeight: true, //enable auto height to use more with content in slides. Not for images
#
# 	});
#
# });
# </script>
# 	<script>jQuery(document).ready(function(){
# 	var sliderck311 = new Swiper('#sliderck311', {
#
# 		setWrapperSize: true, // nécessaire pour garder les images centrées lors de la réduction de la fenêtre
# 		slidesPerView: 'auto',
# 		slidesPerGroup: 1,
# 		slidesPerColumn: 1,
# 		spaceBetween: 30,
# 		centeredSlides: true,
# 		initialSlide: 0,
# 		freeMode: 0,
# 		speed: 3000,
# 		autoplay: 1,
# 		autoplayDisableOnInteraction: true,
# 		autoplayStopOnLast: 1,
# 		autoplayPauseOnOver: false,
# 		effect: 'slide',
# 		fade: {crossFade: true},
# 		loop: true,
# 		loopedSlides: 78,
# 		keyboardControl: 0,
# 		mousewheelControl: 0,
# 		a11y: true,
# 		paginationType: 'none', // 'bullets' or 'progress' or 'fraction' or 'custom'
#
# 		// direction: 'horizontal',
# 		// autoHeight: true, //enable auto height to use more with content in slides. Not for images
#
# 	});
#
# });
# </script>
# 	<script>jQuery(document).ready(function(){
# 	var sliderck316 = new Swiper('#sliderck316', {
#
# 		setWrapperSize: true, // nécessaire pour garder les images centrées lors de la réduction de la fenêtre
# 		slidesPerView: 'auto',
# 		slidesPerGroup: 1,
# 		slidesPerColumn: 1,
# 		spaceBetween: 30,
# 		centeredSlides: true,
# 		initialSlide: 0,
# 		freeMode: 0,
# 		speed: 3000,
# 		autoplay: 1,
# 		autoplayDisableOnInteraction: true,
# 		autoplayStopOnLast: 1,
# 		autoplayPauseOnOver: false,
# 		effect: 'slide',
# 		fade: {crossFade: true},
# 		loop: true,
# 		loopedSlides: 7,
# 		keyboardControl: 0,
# 		mousewheelControl: 0,
# 		a11y: true,
# 		paginationType: 'none', // 'bullets' or 'progress' or 'fraction' or 'custom'
#
# 		// direction: 'horizontal',
# 		// autoHeight: true, //enable auto height to use more with content in slides. Not for images
#
# 	});
#
# });
# </script>
# 	<link href="https://kbtu.edu.kz/kz/" rel="alternate" hreflang="x-default">
#
# </head>
#
#
#
# <body class="site com_content wrapper-static view-featured no-layout no-task itemid-1587">
#
# <div class="overlay" ></div>
#
#     <header id="header" class="header container-header full-width position-sticky sticky-top">
#
#
# 	<div class="container">
#
# 	<div class="row">
#
#
#                     <div class="grid-child container-below-top">
#                 <div class="moduletable ">
#
# <form class="mod-finder js-finder-searchform form-search" action="/ru/rezultaty-poiska" method="get" role="search">
#     <label for="mod-finder-searchword295" class="visually-hidden finder">Поиск</label><div class="mod-finder__search input-group"><input type="text" name="q" id="mod-finder-searchword295" class="js-finder-search-query form-control" value="" placeholder="Введите текст..."><button class="btn btn-primary" type="submit"><span class="icon-search icon-white" aria-hidden="true"></span> Поиск</button></div>
#             </form>
# </div>
# <div class="mod-languages">
#     <p class="visually-hidden" id="language_picker_des_300">Выберите язык</p>
#
#
#     <ul aria-labelledby="language_picker_des_300" class="mod-languages__list lang-inline">
#
#                                 <li>
#                 <a  href="/kz/">
#                                             KZ                                    </a>
#             </li>
#                                                     <li class="lang-active">
#                 <a aria-current="true"  href="https://kbtu.edu.kz/ru/">
#                                             RU                                    </a>
#             </li>
#                                         <li>
#                 <a  href="/en/">
#                                             EN                                    </a>
#             </li>
#                 </ul>
#
# </div>
#
#             </div>
#
#                     <div class="grid-child">
#                 <div class="navbar-brand">
#                     <a class="brand-logo" href="/">
#                         <img loading="eager" decoding="async" class="noanimate" src="https://kbtu.edu.kz/images/logo_blue.png" alt="joomla kbtu" width="2500" height="585">                    </a>
#                                     </div>
#             </div>
#
#                     <div class="grid-child container-nav">
#                                     <div class="left_block">
#
# <div class="left_block_btn" >
#
# 	<div class="hamburger">
#
# 	<span class="s1"></span>
# 	<span class="s2"></span>
# 	<span class="s3"></span>
#
# 	</div>
#
# </div>
#
# <div class="main-menu-block">
#
# <ul class="mod-menu mod-list nav main-menu ">
# <li class="nav-item item-1347 deeper parent-icon "><a href="#" >Об университете</a><div class="sub-menu-block" ><ul class="mod-menu__sub list-unstyled sub-menu" ><li class="nav-item item-972"><a href="/ru/ob-universitete/o-nas" >О нас </a></li><li class="nav-item item-155"><a href="/ru/ob-universitete/blog-rektora" >Обращение Ректора</a></li><li class="nav-item item-146"><a href="/ru/ob-universitete/history" >История</a></li><li class="nav-item item-147"><a href="/ru/ob-universitete/missiya-i-strategiya" >Миссия и стратегия</a></li><li class="nav-item item-715"><a href="/ru/ob-universitete/otchety-rektora" >Отчеты ректора
#
# </div>
#
#
#
# 	<ul class="social_icons">
#
#
# 	<li class="icon-telegram"><a href="https://t.me/kbtuadmission"><i class="fa fa-telegram"></i></a></li>
# 	<li class="icon-facebook"><a href="https://www.facebook.com/share/16h9YWYh4a/?mibextid=wwXIfr"><i class="fa-brands fa-facebook"></i></a></li>
# 	<li class="icon-youtube"><a href="https://youtube.com/@kbtuofficialchannel?si=2owNsMTSAeAFez-G"><i class="fa-brands fa-square-youtube"></i></a></li>
# 	<li class="icon-tiktok"><a href="https://www.tiktok.com/@kbtu_official?_t=ZM-8xMCIALO88c&_r=1"><i class="fa-brands fa-tiktok"></i></a></li>
# 	<li class="icon-instagram"><a href="https://www.instagram.com/kbtu_official?igsh=MXZjNHlxamU3bGYyYQ%3D%3D&utm_source=qr"><i class="fa fa-instagram"></i></a></li>
#
# 	</ul>
#
#
# </div>
#
#                                             </div>
#
# 		</div>
#
# 		</div>
#
#     </header>
#
#     <div class="site-grid">
#                     <div class="container-banner ">
#                 <div class="banner no-card block_main_slider">
#         <div class="swiper-container swiper-layout-over block_main_slider" id="sliderck315" dir="ltr" data-effect="slide">
# 	<div class="swiper-wrapper">
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/event_19022026_rus.png')">
# 				<img class="swiper-img" alt="" src="/images/event_19022026_rus.png" />
# 							</figure>
# 						<a aria-label="" class=" swiper-link" href="/activity/5052-v-kbtu-projdet-pervaya-v-tsentralnoj-azii-nauchnaya-konferentsiya-po-issledovaniyu-videoigr-digra-central-asia-conference"></a>		</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/banner_18022026_rus.jpg')">
# 				<img class="swiper-img" alt="" src="/images/banner_18022026_rus.jpg" />
# 							</figure>
# 						<a aria-label="" class=" swiper-link" href="/activity/5047-mezhdunarodnaya-molodezhnaya-nauchno-prakticheskaya-konferentsiya"></a>		</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/iwcf_banner_12112025_rus.png')">
# 				<img class="swiper-img" alt="" src="/images/iwcf_banner_12112025_rus.png" />
# 							</figure>
# 						<a aria-label="" class=" swiper-link" href="/akademiya-korporativnogo-obrazovaniya/nepreryvnoe-obrazovanie/4911-mezhdunarodnaya-sertifikatsiya-iwcf"></a>		</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/pr_banner_2025_3_rus.png')">
# 				<img class="swiper-img" alt="" src="/images/pr_banner_2025_3_rus.png" />
# 							</figure>
# 						<a aria-label="" class=" swiper-link" href="/priemnaya-komissiya-kbtu"></a>		</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/main_banner_bp_ru.jpg')">
# 				<img class="swiper-img" alt="" src="/images/main_banner_bp_ru.jpg" />
# 							</figure>
# 						<a aria-label="" class=" swiper-link" href="/akademiya-korporativnogo-obrazovaniya"></a>		</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/main_banner_new_2025_ru.jpg')">
# 				<img class="swiper-img" alt="" src="/images/main_banner_new_2025_ru.jpg" />
# 							</figure>
# 						<a aria-label="" class=" swiper-link" href="/novye-obrazovatelnye-programmy-kbtu-2025"></a>		</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/UNIVERSITY_OF_LONDON_RUS.jpg')">
# 				<img class="swiper-img" alt="" src="/images/UNIVERSITY_OF_LONDON_RUS.jpg" />
# 							</figure>
# 						<a aria-label="" class=" swiper-link" href="https://gd.kbtu.kz/" target="_blank"></a>		</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/GRI_baner_RU.png')">
# 				<img class="swiper-img" alt="" src="/images/GRI_baner_RU.png" />
# 							</figure>
# 						<a aria-label="" class=" swiper-link" href="/ob-universitete/tsentr-esg-kompetentsij-kbtu"></a>		</div>
# 			</div>
# 		<div class="swiper-pagination"></div>
# 		</div>
#
# </div>
#
#             </div>
#
#                     <div class="grid-child container-top-a">
#                 <div class="top-a no-card ">
#
# <div id="mod-custom309" class="mod-custom custom">
#     <div class="row">
# <div class="col-6 col-md-3 p-2">
# <div class="statistic_block "><span class="title">Год основания</span><span class="count count_1">2001</span></div>
# </div>
# <div class=" col-6 col-md-3 p-2">
# <div class="statistic_block "><span class="title">Обучающихся</span> <span class="count count_2">7746</span></div>
# </div>
# <div class=" col-6 col-md-3 p-2">
# <div class="statistic_block "><span class="title">Трудоустройство</span> <span class="count count_3">98%</span></div>
# </div>
# <div class=" col-6 col-md-3 p-2">
# <div class="statistic_block "><span class="title">Школ</span> <span class="count count_4">10</span></div>
# </div>
# </div></div>
# </div>
#
#             </div>
#
#                     <div class="grid-child container-top-b">
#                 <div class="top-b no-card ">
#
# <div id="mod-custom310" class="mod-custom custom">
#     <div class="row ">
# <div class="col-sm-12 col-md-4 p-2">
# <div class="learn_main_block">
# <div class="main_img"><img class="float-none" src="/images/learn_img.jpg"></div>
# <div class="learn_block"><a href="/priemnaya-komissiya-bakalavriat">
# <div class="title">БАКАЛАВРИАТ</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# </div>
# <div class="col-sm-12 col-md-8 p-0">
# <div class="row">
# <div class="col-12 p-2">
# <div class="learn_block"><a href="/priemnaya-komissiya-magistratura">
# <div class="title">Магистратура</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# <div class="col-12 p-2">
# <div class="learn_block"><a href="/priemnaya-komissiya-doctorantura">
# <div class="title">Докторантура</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# <div class="col-12 p-2">
# <div class="learn_block"><a href="/akademiya-korporativnogo-obrazovaniya">
# <div class="title">Академия корпоративного образования</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# <div class="col-12 p-2">
# <div class="learn_block"><a href="/internatsionalizatsiya/priem-inostrannykh-abiturientov">
# <div class="title">International Admission</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# <div class="col-12 p-2">
# <div class="learn_block"><a href="https://gd.kbtu.kz/">
# <div class="title">Graduate Diploma</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# </div>
# </div>
# </div></div>
# </div>
#
#             </div>
#
#
#         <div class="grid-child container-component">
#
#
#             <div id="system-message-container" aria-live="polite"></div>
#
#             <main>
#                 <div class="blog-featured">
#
#
#
#
#
# </div>
#             </main>
#
#         </div>
#
#
#                     <div class="grid-child container-bottom-a">
#                 <div class="bottom-a card block_events">
#             <h1 class="card-header ">События</h1>        <div class="card-body">
#                         <ul class="mod-articles-items mod-list ">
#                     <li>
#             <article class="mod-articles-item" itemscope itemtype="https://schema.org/Article">
#
#                                     <div class="mod-articles-item-content">
#
#                                                                                 <h4 class="mod-articles-title" itemprop="name">
#                                                                                                                                                                                 <a href="/ru/activity/5052-v-kbtu-projdet-pervaya-v-tsentralnoj-azii-nauchnaya-konferentsiya-po-issledovaniyu-videoigr-digra-central-asia-conference" class="mod-articles-link " itemprop="url"><span><div>В КБТУ пройдет первая в Центральной Азии научная конференция по исследованию видеоигр DiGRA Central Asia Conference</div></span></a>                                                            </h4>
#
#
#
#                                                     <figure class="mod-articles-image item-image">
#             <img src="/images/event_19022026_rus.png" width="1320" height="550" loading="lazy">        </figure>
#
#
#
#                                                     <p>21 февраля 2026 года в Казахстанско-Британском Техническом Университете (КБТУ) состоится первая в</p>...
#
#                                             </div>
#                             </article>
#         </li>
#                     <li>
#             <article class="mod-articles-item" itemscope itemtype="https://schema.org/Article">
#
#                                     <div class="mod-articles-item-content">
#
#                                                                                 <h4 class="mod-articles-title" itemprop="name">
#                                                                                                                                                                                 <a href="/ru/activity/5050-vysshee-obrazovanie-i-nauka-god-tsifrovizatsii-i-iskusstvennogo-intellekta" class="mod-articles-link " itemprop="url"><span><div>Высшее образование и наука: год цифровизации и искусственного интеллекта</div></span></a>                                                            </h4>
#
#
#
#                                                     <figure class="mod-articles-image item-image">
#             <img src="/images/event_16022026.jpg" width="1500" height="1000" loading="lazy">        </figure>
#
#
#
#                                                     <p>12–13 февраля 2026 года в Казахском национальном исследовательском техническом университете имени К. И.</p>...
#
#                                             </div>
#                             </article>
#         </li>
#                     <li>
#             <article class="mod-articles-item" itemscope itemtype="https://schema.org/Article">
#
#                                     <div class="mod-articles-item-content">
#
#                                                                                 <h4 class="mod-articles-title" itemprop="name">
#                                                                                                                                                                                 <a href="/ru/activity/5047-mezhdunarodnaya-molodezhnaya-nauchno-prakticheskaya-konferentsiya" class="mod-articles-link " itemprop="url"><span><div>Международная молодежная научно-практическая конференция</div></span></a>                                                            </h4>
#
#
#
#                                                     <figure class="mod-articles-image item-image">
#             <img src="/images/banner_18022026_rus.jpg" width="1320" height="550" loading="lazy">        </figure>
#
#
#
#                                                     <p>9–10 апреля 2026 года в КБТУ по инициативе Школы энергетики и нефтегазовой индустрии состоится</p>...
#
#                                             </div>
#                             </article>
#         </li>
#                     <li>
#             <article class="mod-articles-item" itemscope itemtype="https://schema.org/Article">
#
#                                     <div class="mod-articles-item-content">
#
#                                                                                 <h4 class="mod-articles-title" itemprop="name">
#                                                                                                                                                                                 <a href="/ru/activity/5016-luchshij-prepodavatel-vuza-2025" class="mod-articles-link " itemprop="url"><span><div>Лучший преподаватель вуза – 2025</div></span></a>                                                            </h4>
#
#
#
#                                                     <figure class="mod-articles-image item-image">
#             <img src="/images/event_18112025.jpg" width="3240" height="3240" loading="lazy">        </figure>
#
#
#
#                                                     <p>Казахстанко-Британский технический университет сообщает о публикации итогов первого этапа</p>...
#
#                                             </div>
#                             </article>
#         </li>
#                     <li>
#             <article class="mod-articles-item" itemscope itemtype="https://schema.org/Article">
#
#                                     <div class="mod-articles-item-content">
#
#                                                                                 <h4 class="mod-articles-title" itemprop="name">
#                                                                                                                                                                                 <a href="/ru/activity/4962-akademicheskaya-mobilnost-v-yuzhnuyu-koreyu" class="mod-articles-link " itemprop="url"><span><div>Академическая мобильность в Южную Корею </div></span></a>                                                            </h4>
#
#
#
#                                                     <figure class="mod-articles-image item-image">
#             <img src="/images/photo_5332293445668173331_y.jpg" width="1024" height="1280" loading="lazy">        </figure>
#
#
#
#                                                     <p>Сообщаем, что южнокорейские университеты Gwangju Institute of Science and Technology (GIST) и</p>...
#
#                                             </div>
#                             </article>
#         </li>
#     </ul>
#     </div>
# </div>
#
# <div id="mod-custom96" class="mod-custom custom">
#     <p><a class="btn btn_category" href="/activity">ВСЕ СОБЫТИЯ</a></p></div>
#
#             </div>
#
#                     <div class="grid-child container-bottom-b">
#                 <div class="bottom-b card block_main_prof_man">
#             <h3 class="card-header ">Профессорско-преподавательский состав</h3>        <div class="card-body">
#                 <div class="swiper-container swiper-layout-over block_main_prof_man" id="sliderck314" dir="ltr" data-effect="slide">
# 	<div class="swiper-wrapper">
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/PAUL_DAVIS.png')">
# 				<img class="swiper-img" alt="Дэвис Пол Джеймс <span class='prof'>Профессор</span>" src="/images/PAUL_DAVIS.png" />
# 							</figure>
# 						<div class="swiper-caption">
# 								<div class="swiper-title">
# 					Дэвис Пол Джеймс <span class='prof'>Профессор</span>				</div>
# 												<div class="swiper-desc">
# 					Бизнес Школа				</div>
# 																			</div>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/PAKIZAR_S_SHAMOI.png')">
# 				<img class="swiper-img" alt="Шамои Пакизар Сулгадиновна <span class='prof'>Профессор</span>" src="/images/PAKIZAR_S_SHAMOI.png" />
# 							</figure>
# 						<div class="swiper-caption">
# 								<div class="swiper-title">
# 					Шамои Пакизар Сулгадиновна <span class='prof'>Профессор</span>				</div>
# 												<div class="swiper-desc">
# 					Школа информационных технологий и инженерии				</div>
# 																			</div>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/laumunin_chokan.jpg')">
# 				<img class="swiper-img" alt="Лаумулин Чокан Турарович<span class='prof'>Профессор</span>" src="/images/laumunin_chokan.jpg" />
# 							</figure>
# 						<div class="swiper-caption">
# 								<div class="swiper-title">
# 					Лаумулин Чокан Турарович<span class='prof'>Профессор</span>				</div>
# 												<div class="swiper-desc">
# 					Школа естественных и социальных наук				</div>
# 																			</div>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/turgazinov_ilas.jpg')">
# 				<img class="swiper-img" alt="Тургазинов Ильяс Казбекұлы<span class='prof'>Ассистент-профессор</span>" src="/images/turgazinov_ilas.jpg" />
# 							</figure>
# 						<div class="swiper-caption">
# 								<div class="swiper-title">
# 					Тургазинов Ильяс Казбекұлы<span class='prof'>Ассистент-профессор</span>				</div>
# 												<div class="swiper-desc">
# 					Школа энергетики и нефтегазовой индустрии				</div>
# 																			</div>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/ZHAMAL_S_TULEMISSOVA.jpg')">
# 				<img class="swiper-img" alt="Тулемисова Жамал Сериковна<span class='prof'>Ассоциированный профессор</span>" src="/images/ZHAMAL_S_TULEMISSOVA.jpg" />
# 							</figure>
# 						<div class="swiper-caption">
# 								<div class="swiper-title">
# 					Тулемисова Жамал Сериковна<span class='prof'>Ассоциированный профессор</span>				</div>
# 												<div class="swiper-desc">
# 					Школа геологии				</div>
# 																			</div>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/ASKAR_S_DZHUMADILDAYEV.png')">
# 				<img class="swiper-img" alt="Джумадильдаев Аскар Серкулович<span class='prof'>Профессор</span>" src="/images/ASKAR_S_DZHUMADILDAYEV.png" />
# 							</figure>
# 						<div class="swiper-caption">
# 								<div class="swiper-title">
# 					Джумадильдаев Аскар Серкулович<span class='prof'>Профессор</span>				</div>
# 												<div class="swiper-desc">
# 					Школа прикладной математики				</div>
# 																			</div>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/KAIR_KH_NUSSUPOV.png')">
# 				<img class="swiper-img" alt="Нусупов Каир Хамзаевич<span class='prof'>Профессор</span>" src="/images/KAIR_KH_NUSSUPOV.png" />
# 							</figure>
# 						<div class="swiper-caption">
# 								<div class="swiper-title">
# 					Нусупов Каир Хамзаевич<span class='prof'>Профессор</span>				</div>
# 												<div class="swiper-desc">
# 					Школа материаловедения и зеленых технологий				</div>
# 																			</div>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/aidarova_saule.jpg')">
# 				<img class="swiper-img" alt="Айдарова Сауле Байляровна<span class='prof'>Профессор</span>" src="/images/aidarova_saule.jpg" />
# 							</figure>
# 						<div class="swiper-caption">
# 								<div class="swiper-title">
# 					Айдарова Сауле Байляровна<span class='prof'>Профессор</span>				</div>
# 												<div class="swiper-desc">
# 					Школа материаловедения и зеленых технологий				</div>
# 																			</div>
# 								</div>
# 			</div>
# 		<div class="swiper-pagination"></div>
# 		</div>
#
#     </div>
# </div>
#
#             </div>
#
# 		            <div class="grid-child container-bottom-c">
#                 <div class="bottom-c card block_news">
#             <h1 class="card-header ">Новости</h1>        <div class="card-body">
#                         <ul class="mod-articles-items mod-list ">
#                     <li>
#             <article class="mod-articles-item" itemscope itemtype="https://schema.org/Article">
#
#                                     <div class="mod-articles-item-content">
#
#                                                                                 <h4 class="mod-articles-title" itemprop="name">
#                                                                                                                                                                                 <a href="/ru/novosty/5043-12-e-mesto-iz-34-komand-studenty-kbtu-uspeshno-vystupili-na-shell-eco-marathon-2026-v-katare" class="mod-articles-link " itemprop="url"><span><div>12-е место из 34 команд: студенты КБТУ  успешно выступили на Shell Eco-Marathon 2026 в Катаре</div></span></a>                                                            </h4>
#
#
#                                                                                 <dl class="list-unstyled">
#                                 <dt class="article-info-term">
#                                     <span class="visually-hidden">
#                                         Информация о материале                                    </span>
#                                 </dt>
#
#
#
#                                                                     <dd class="mod-articles-date ">
#                                         <span class="icon-calendar icon-fw" aria-hidden="true"></span>                                        2026-02-06 17:37:42                                    </dd>
#
#                                                             </dl>
#
#                                                     <figure class="mod-articles-image item-image">
#             <img src="/images/new_06022026.jpg" width="1280" height="853" loading="lazy">        </figure>
#
#
#
#
#
#
# <p class="readmore">
#             <a href="/ru/novosty/5043-12-e-mesto-iz-34-komand-studenty-kbtu-uspeshno-vystupili-na-shell-eco-marathon-2026-v-katare" aria-label="Подробнее: 12-е место из 34 команд: студенты КБТУ  успешно выступили на Shell Eco-Marathon 2026 в Катаре">
#             Узнать подробнее        </a>
#     </p>
#                                             </div>
#                             </article>
#         </li>
#                     <li>
#             <article class="mod-articles-item" itemscope itemtype="https://schema.org/Article">
#
#                                     <div class="mod-articles-item-content">
#
#                                                                                 <h4 class="mod-articles-title" itemprop="name">
#                                                                                                                                                                                 <a href="/ru/novosty/5037-delegatsiya-kbtu-provela-vstrechi-s-sanda-university-i-wuchuang-group" class="mod-articles-link " itemprop="url"><span><div>Делегация КБТУ провела встречи с Sanda University и Wuchuang Group</div></span></a>                                                            </h4>
#
#
#                                                                                 <dl class="list-unstyled">
#                                 <dt class="article-info-term">
#                                     <span class="visually-hidden">
#                                         Информация о материале                                    </span>
#                                 </dt>
#
#
#
#                                                                     <dd class="mod-articles-date ">
#                                         <span class="icon-calendar icon-fw" aria-hidden="true"></span>                                        2025-12-31 09:52:03                                    </dd>
#
#                                                             </dl>
#
#                                                     <figure class="mod-articles-image item-image">
#             <img src="/images/photo_5377783471528415000_y.jpg" width="1280" height="960" loading="lazy">        </figure>
#
#
#
#
#
#
# <p class="readmore">
#             <a href="/ru/novosty/5037-delegatsiya-kbtu-provela-vstrechi-s-sanda-university-i-wuchuang-group" aria-label="Подробнее: Делегация КБТУ провела встречи с Sanda University и Wuchuang Group">
#             Узнать подробнее        </a>
#     </p>
#                                             </div>
#                             </article>
#         </li>
#                     <li>
#             <article class="mod-articles-item" itemscope itemtype="https://schema.org/Article">
#
#                                     <div class="mod-articles-item-content">
#
#                                                                                 <h4 class="mod-articles-title" itemprop="name">
#                                                                                                                                                                                 <a href="/ru/novosty/5034-delegatsiya-kbtu-provela-rabochie-vstrechi-v-shankhajskom-universitete-tszyaotun" class="mod-articles-link " itemprop="url"><span><div>Делегация КБТУ провела рабочие встречи в Шанхайском университете Цзяотун</div></span></a>                                                            </h4>
#
#
#                                                                                 <dl class="list-unstyled">
#                                 <dt class="article-info-term">
#                                     <span class="visually-hidden">
#                                         Информация о материале                                    </span>
#                                 </dt>
#
#
#
#                                                                     <dd class="mod-articles-date ">
#                                         <span class="icon-calendar icon-fw" aria-hidden="true"></span>                                        2025-12-30 15:40:19                                    </dd>
#
#                                                             </dl>
#
#                                                     <figure class="mod-articles-image item-image">
#             <img src="/images/new_3012025.jpg" width="1280" height="960" loading="lazy">        </figure>
#
#
#
#
#
#
# <p class="readmore">
#             <a href="/ru/novosty/5034-delegatsiya-kbtu-provela-rabochie-vstrechi-v-shankhajskom-universitete-tszyaotun" aria-label="Подробнее: Делегация КБТУ провела рабочие встречи в Шанхайском университете Цзяотун">
#             Узнать подробнее        </a>
#     </p>
#                                             </div>
#                             </article>
#         </li>
#                     <li>
#             <article class="mod-articles-item" itemscope itemtype="https://schema.org/Article">
#
#                                     <div class="mod-articles-item-content">
#
#                                                                                 <h4 class="mod-articles-title" itemprop="name">
#                                                                                                                                                                                 <a href="/ru/novosty/5032-konkurs-vakantnykh-grantov-kbtu-2025-2026-rus" class="mod-articles-link " itemprop="url"><span><div>КОНКУРС ВАКАНТНЫХ ГРАНТОВ КБТУ</div></span></a>                                                            </h4>
#
#
#                                                                                 <dl class="list-unstyled">
#                                 <dt class="article-info-term">
#                                     <span class="visually-hidden">
#                                         Информация о материале                                    </span>
#                                 </dt>
#
#
#
#                                                                     <dd class="mod-articles-date ">
#                                         <span class="icon-calendar icon-fw" aria-hidden="true"></span>                                        2025-12-11 15:57:25                                    </dd>
#
#                                                             </dl>
#
#                                                     <figure class="mod-articles-image item-image">
#             <img src="/images/new_17062024_3_rus.jpg" width="1320" height="640" loading="lazy">        </figure>
#
#
#
#
#
#
# <p class="readmore">
#             <a href="/ru/novosty/5032-konkurs-vakantnykh-grantov-kbtu-2025-2026-rus" aria-label="Подробнее: КОНКУРС ВАКАНТНЫХ ГРАНТОВ КБТУ">
#             Узнать подробнее        </a>
#     </p>
#                                             </div>
#                             </article>
#         </li>
#     </ul>
#     </div>
# </div>
#
# <div id="mod-custom318" class="mod-custom custom">
#     <p><a class="btn btn_category" href="/novosty">ВСЕ НОВОСТИ</a></p></div>
#
#             </div>
#
# 		            <div class="grid-child container-bottom-d ">
#                 <div class="bottom-d card block_own_partners">
#             <h3 class="card-header ">Наши партнеры</h3>        <div class="card-body">
#                 <div class="swiper-container swiper-layout-over block_own_partners" id="sliderck311" dir="ltr" data-effect="slide">
# 	<div class="swiper-wrapper">
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/adal_logo.png')">
# 				<img class="swiper-img" alt="" src="/images/adal_logo.png" />
# 							</figure>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/su_logo.png')">
# 				<img class="swiper-img" alt="" src="/images/su_logo.png" />
# 							</figure>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/partner/part1-min.png')">
# 				<img class="swiper-img" alt="" src="/images/partner/part1-min.png" />
# 							</figure>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/partner/part2-min.png')">
# 				<img class="swiper-img" alt="" src="/images/partner/part2-min.png" />
# 							</figure>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/partner/part3-min.png')">
# 				<img class="swiper-img" alt="" src="/images/partner/part3-min.png" />
# 							</figure>
# 								</div>
# 				<div class="swiper-slide">
# 						<figure class="swiper-img-cont" style="background-image:url('/images/partner/part4-min.png')">
# 				<img class="swiper-img" alt="" src="/images/partner/part4-min.png" />
# 							</figure>
# 								</div>
# 				<div class="swiper-slide">
# ...
# <div class="address">Республика Казахстан, 050000, Алматы, ул. Толе би, 59</div>
# <div class="email"><a href="mailto:kense@kbtu.kz">kense@kbtu.kz</a></div>
# <div class="email"><a href="mailto:helpdesk@kbtu.kz">helpdesk@kbtu.kz</a></div>
# </div>
# <div class="col-md-3 col-12">
# <div class="title">Образование</div>
# <div class="other_data"><a href="/priemnaya-komissiya-bakalavriat">Бакалавриат</a></div>
# <div class="other_data"><a href="/priemnaya-komissiya-magistratura">Магистратура</a></div>
# <div class="other_data"><a href="/priemnaya-komissiya-doctorantura">Докторантура</a></div>
# <div class="other_data"><a href="/akademiya-korporativnogo-obrazovaniya">Академия корпоративного образования</a></div>
# <div class="other_data"><a href="/internatsionalizatsiya/priem-inostrannykh-abiturientov">International admission</a></div>
# </div>
# <div class="col-md-3 col-12">
# <div class="title">Приемная комиссия</div>
# <div class="phone">+7 (727) 357 42 51</div>
# <div class="email"><a href="mailto:admission@kbtu.kz">admission@kbtu.kz</a></div>
# </div>
# <div class="col-md-3 col-12">
# <div class="title">Полезные ссылки</div>
# <div class="other_data"><a href="/vacancy">Вакансии</a></div>
# <div class="other_data"><a href="/zakupki">Закупки</a></div>
# </div>
# </div>
# <div class="row m-0 mt-4">
# <div class="col-12 text-center">
# <p class="noanimate m-0 other_data">Любое использование материалов допускается только при наличии гиперссылки на <span style="text-decoration: underline;"><a href="https://kbtu.edu.kz/"><strong>https://kbtu.edu.kz</strong></a></span></p>
# </div>
# </div></div>
# </div>
#
#             </div>
#
#
#
# 		</footer>
#
#
#
#
#
#
#
# <!-- -->
#
# <script>
#
# document.addEventListener("DOMContentLoaded", function () {
#
# /*
#
#     document.getElementById("form_ako").addEventListener("submit", async function (e) {
#         e.preventDefault(); // Останавливаем отправку формы
#
#         // Получаем значение уникального номера из формы
#         const certNumber = document.querySelector("input[name='certNumber']").value;
#
#         // Запрос к вашему API
#         const response = await fetch("https://script.google.com/macros/s/AKfycbyq2s77bKopALN18Oa-DLZNpOxdDbfoZOWs_7xocYobAVVBVnJvPX1bmmu6-RRGyO0ziA/exec" + certNumber);
#         const result = await response.json();
#
#         // Показываем результат
#         const resultDiv = document.getElementById("result");
#         if (result.error) {
#             resultDiv.innerHTML = `<p style="color: red;">${result.error}</p>`;
#         } else {
#             resultDiv.innerHTML = `
#                 <p>ФИО владельца: ${result.name}</p>
#                 <p>Дата получения: ${result.date}</p>
#                 <p>Курс: ${result.course}</p>
#                 <p>Комментарий: ${result.comment}</p>
#             `;
#         }
#
#         resultDiv.style.display = "block"; // Показываем результат
#     });
#
# */
#
# <!-- -->
#
#
#   // === Ваш публичный деплой GAS ===
#   const ACEV_BASE = "https://script.google.com/macros/s/AKfycbxxwAdjYRhANoLoXjOwb1KpXqJ1BkU3AdfiMEplCXRori17x-rh4e0Lb7qpXAaTgt5J/exec";
#
#   // === Определяем язык строго по вашему URL-формату ===
#   function acevGetLangFromUrl() {
#     const p = (location.pathname || "").toLowerCase();
#     if (p.startsWith("/en/")) return "en";
#     if (p.startsWith("/kz/")) return "kk";
#     return "ru"; // по умолчанию
#   }
#   const ACEV_LANG = acevGetLangFromUrl();
#
#   const ACEV_I18N = {
#     ru: {
#       btnOpen: "Верификация сертификата АКО",
#       modalTitle: "ID сертификата",
#       ariaCloseX: "Закрыть",
#       placeholder: "Например: DCP05-14-99999999",
#       hintPrefix: "Поддерживаются ID формата",
#       notRun: "Запрос ещё не выполнялся.",
#       btnSubmit: "Проверить",
#       btnClose: "Закрыть",
#       enterId: "Введите ID сертификата",
#       checking: "Проверяем…",
#       notFound: "Сертификат не найден",
#       requestError: "Ошибка запроса. Попробуйте позже или обратитесь в техподдержку.",
#       fio: "ФИО владельца",
#       course: "Курс",
#       dates: "Даты",
#       duration: "Продолжительность",
#       trainer: "Тренер",
#       id: "ID",
#       dash: "—"
#     },
#     en: {
#       btnOpen: "ACE Certificate Verification",
#       modalTitle: "Certificate ID",
#       ariaCloseX: "Close",
#       placeholder: "For example: DCP05-14-99999999",
#       hintPrefix: "Supported ID formats",
#       notRun: "No request has been made yet.",
#       btnSubmit: "Verify",
#       btnClose: "Close",
#       enterId: "Enter the certificate ID",
#       checking: "Verifying…",
#       notFound: "Certificate not found",
#       requestError: "Request error. Please try again later or contact support.",
#       fio: "Certificate holder",
#       course: "Course",
#       dates: "Dates",
#       duration: "Duration",
#       trainer: "Trainer",
#       id: "ID",
#       dash: "—"
#     },
#     kk: {
#       btnOpen: "КБА сертификатын тексеру",
#       modalTitle: "Сертификаттың ID нөмірі",
#       ariaCloseX: "Жабу",
#       placeholder: "Мысалы: DCP05-14-99999999",
#       hintPrefix: "Қолдау көрсетілетін ID форматтары",
#       notRun: "Сұраныс әлі орындалған жоқ.",
#       btnSubmit: "Тексеру",
#       btnClose: "Жабу",
#       enterId: "Сертификат ID енгізіңіз",
#       checking: "Тексерілуде…",
#       notFound: "Сертификат табылмады",
#       requestError: "Сұрау қатесі. Кейінірек қайталап көріңіз немесе техникалық қолдауға жүгініңіз.",
#       fio: "Иесінің аты-жөні",
#       course: "Курс",
#       dates: "Күндер",
#       duration: "Ұзақтығы",
#       trainer: "Тренер",
#       id: "ID",
#       dash: "—"
#     }
#   };
#
#   function acevT(key) {
#     return (ACEV_I18N[ACEV_LANG] && ACEV_I18N[ACEV_LANG][key])
#       ? ACEV_I18N[ACEV_LANG][key]
#       : (ACEV_I18N.ru[key] || key);
#   }
#
#   // DOM
#   const acevForm    = document.getElementById("acev-form");
#   const acevInput   = document.getElementById("acev-certNumber");
#   const acevBox     = document.getElementById("acev-result");
#   const acevBtn     = document.getElementById("acev-submit");
#   const acevBtnOpen = document.getElementById("acev-btn-open");
#   const acevTitle   = document.getElementById("acevModalLabel");
#   const acevHint    = document.getElementById("acev-hint");
#   const acevCloseX  = document.getElementById("acev-btn-close-x");
#   const acevClose   = document.getElementById("acev-btn-close");
#
#   // Локализация UI
#   if (acevBtnOpen) acevBtnOpen.textContent = acevT("btnOpen");
#   if (acevTitle)   acevTitle.textContent = acevT("modalTitle");
#   if (acevCloseX)  acevCloseX.setAttribute("aria-label", acevT("ariaCloseX"));
#   if (acevInput)   acevInput.placeholder = acevT("placeholder");
#   if (acevBtn)     acevBtn.textContent = acevT("btnSubmit");
#   if (acevClose)   acevClose.textContent = acevT("btnClose");
#   if (acevBox)     acevBox.textContent = acevT("notRun");
#
#   // Подсказка: сохраняем <code>, меняем вводную фразу
#   if (acevHint) {
#     const codes = Array.from(acevHint.querySelectorAll("code")).map(c => c.outerHTML).join(", ");
#     acevHint.innerHTML = `${acevEscapeHtml(acevT("hintPrefix"))} ${codes}`;
#   }
#
#   acevForm.addEventListener("submit", acevOnSubmit);
#
#   // Автозапуск по параметру: ?id=... или ?q=...
#   (function acevBootstrapFromQuery() {
#     const p = new URLSearchParams(location.search);
#     const q = p.get("id") || p.get("q");
#     if (q) {
#       acevInput.value = q;
#       setTimeout(() => acevForm.requestSubmit(), 0);
#     }
#   })();
#
#   async function acevOnSubmit(e) {
#     e.preventDefault();
#     const id = acevNormalizeId(acevInput.value);
#
#     acevBox.style.display = "block";
#     if (!id) {
#       acevBox.innerHTML = `<p class="text-danger mb-0">${acevEscapeHtml(acevT("enterId"))}</p>`;
#       return;
#     }
#
#     acevBtn.disabled = true;
#     acevInput.disabled = true;
#     acevBox.textContent = acevT("checking");
#
#     try {
#       // Если захотите локализовать ответы на стороне GAS — добавьте &lang=
#       // const url = ACEV_BASE + "?id=" + encodeURIComponent(id) + "&lang=" + encodeURIComponent(ACEV_LANG);
#       const url = ACEV_BASE + "?id=" + encodeURIComponent(id);
#
#       const resp = await fetch(url, { method: "GET", mode: "cors", cache: "no-store" });
#       if (!resp.ok) throw new Error("HTTP " + resp.status);
#       const res = await resp.json();
#
#       if (!res.ok) {
#         const msg = (res.message ? String(res.message) : "").trim();
#         const localized = (msg === "Сертификат не найден") ? acevT("notFound") : msg;
#         acevBox.innerHTML = `<p class="text-danger mb-0">${acevEscapeHtml(localized || acevT("notFound"))}</p>`;
#         return;
#       }
#
#       const d = res.data || {};
#       acevBox.innerHTML = [
#         acevRow(acevT("fio"), d.fio),
#         acevRow(acevT("course"), d.course),
#         acevRow(acevT("dates"), d.dates),
#         d.duration ? acevRow(acevT("duration"), d.duration) : "",
#         (d.trainer || d.trainerSign)
#           ? acevRow(
#               acevT("trainer"),
#               acevPrettifyTrainer(d.trainer) + (d.trainerSign ? ` (${d.trainerSign})` : "")
#             )
#           : "",
#         acevRow(acevT("id"), d.id),
#       ].filter(Boolean).join("");
#
#     } catch (err) {
#       console.error(err);
#       acevBox.innerHTML = `<p class="text-danger mb-0">${acevEscapeHtml(acevT("requestError"))}</p>`;
#     } finally {
#       acevBtn.disabled = false;
#       acevInput.disabled = false;
#     }
#   }
#
#   function acevPrettifyTrainer(s){
#     return String(s || "")
#       .split(/\s*\+\s*/g)
#       .map(v => v.trim())
#       .filter(Boolean)
#       .join(", ");
#   }
#
#   function acevRow(label, value) {
#     const v = value ? String(value) : acevT("dash");
#     return `<div class="mb-1"><b>${acevEscapeHtml(label)}:</b> ${acevEscapeHtml(v)}</div>`;
#   }
#
#   function acevNormalizeId(v) {
#     return String(v || "")
#       .replace(/[\u200B-\u200D\uFEFF]/g, "")
#       .replace(/\u00A0/g, " ")
#       .replace(/[–—−‒]/g, "-")
#       .trim();
#   }
#
#   function acevEscapeHtml(s) {
#     return String(s).replace(/[&<>"']/g, m => ({
#       "&":"&amp;", "<":"&lt;", ">":"&gt;", '"':"&quot;", "'":"&#39;"
#     }[m]));
#   }
#
# /*
#
#
#     // Публичный деплой GAS
#     const BASE = "https://script.google.com/macros/s/AKfycbxxwAdjYRhANoLoXjOwb1KpXqJ1BkU3AdfiMEplCXRori17x-rh4e0Lb7qpXAaTgt5J/exec";
#
#     const form  = document.getElementById("verify-form");
#     const input = document.getElementById("certNumber");
#     const box   = document.getElementById("result");
#     const btn   = document.getElementById("submit-btn");
#
#     form.addEventListener("submit", onSubmit);
#
#     // Автозапуск по параметру: verify.html?id=...
#     (function bootstrapFromQuery() {
#       const p = new URLSearchParams(location.search);
#       const q = p.get("id") || p.get("q");
#       if (q) {
#         input.value = q;
#         setTimeout(() => form.requestSubmit(), 0);
#       }
#     })();
#
#     async function onSubmit(e) {
#       e.preventDefault();
#       const id = normalizeId(input.value);
#
#       box.style.display = "block";
#       if (!id) {
#         box.innerHTML = `<p class="err">Введите ID сертификата</p>`;
#         return;
#       }
#
#       btn.disabled = true;
#       input.disabled = true;
#       box.textContent = "Проверяем…";
#
#       try {
#         const url = BASE + "?id=" + encodeURIComponent(id);
#         const resp = await fetch(url, { method: "GET", mode: "cors", cache: "no-store" });
#         if (!resp.ok) throw new Error("HTTP " + resp.status);
#         const res = await resp.json();
#
#         if (!res.ok) {
#           box.innerHTML = `<p class="err">${escapeHtml(res.message || "Сертификат не найден")}</p>`;
#           return;
#         }
#
#         const d = res.data || {};
#         // не показываем департамент и тип
#         box.innerHTML = [
#           row("ФИО владельца", d.fio),
#           row("Курс", d.course),
#           row("Даты", d.dates),
#           d.duration ? row("Продолжительность", d.duration) : "",
#           (d.trainer || d.trainerSign)
#   ? row(
#       "Тренер",
#       prettifyTrainer(d.trainer) + (d.trainerSign ? ` (${d.trainerSign})` : "")
#     )
#   : "",
#           row("ID", d.id),
#         ].filter(Boolean).join("");
#
#       } catch (err) {
#         console.error(err);
#         box.innerHTML = `<p class="err">Ошибка запроса. Попробуйте позже или обратитесь в техподдержку.</p>`;
#       } finally {
#         btn.disabled = false;
#         input.disabled = false;
#       }
#     }
# */
# function prettifyTrainer(s){
#   return String(s || "")
#     .split(/\s*\+\s*/g)
#     .map(v => v.trim())
#     .filter(Boolean)
#     .join(", ");
# }
#
# /*
#     function row(label, value) {
#       return `<div class="row"><b>${escapeHtml(label)}:</b> ${escapeHtml(value || "—")}</div>`;
#     }
#
#     // Нормализация ID: убираем невидимые символы, приводим разные тире к '-'
#     function normalizeId(v) {
#       return String(v || "")
#         .replace(/[\u200B-\u200D\uFEFF]/g, "") // zero-width
#         .replace(/\u00A0/g, " ")               // NBSP → space
#         .replace(/[–—−‒]/g, "-")               // все тире → '-'
#         .trim();
#     }
#
#     function escapeHtml(s) {
#       return String(s).replace(/[&<>"']/g, m => ({
#         "&":"&amp;", "<":"&lt;", ">":"&gt;", '"':"&quot;", "'":"&#39;"
#       }[m]));
#     }
#
# */
#
#
#
# });
#
# </script>
#
# <!-- -->
#
#
#
# <!-- Global Site Tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-77121331-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-77121331-1');
# </script>
# <!-- -->
#
# <!-- Yandex.Metrika counter -->
#     <script type="text/javascript" >
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#    m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a
#    (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#    ym(37283880, "init", {
#         clickmap:true,
#         trackLinks:true,
#         accurateTrackBounce:true
#    });
#    </script>
#    <noscript><div><img src="https://mc.yandex.ru/watch/37283880" style="position:absolute; left:-9999px;" alt="" /></div><
# <!-- /Yandex.Metrika counter -->
#
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window, document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '402685197825792');
# fbq('track', 'PageView');
# </script>
# <noscript><img height="1" width="1" style="display:none"
# src="https://www.facebook.com/tr?id=402685197825792&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Facebook Pixel Code -->
#
# <script type="text/javascript">
# var yaParams = {};
# var xhr = new XMLHttpRequest();
# xhr.open('GET', 'https://ip.up66.ru/', true);
# xhr.onload = function() {
# yaParams.ip = this.responseText;
# }
# xhr.send();
# </script>
#
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript" >
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter83230288 = new Ya.Metrika({
#                     id:83230288,
#                     params:window.yaParams,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true,
#                     webvisor:true
#                 });
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img src="https://mc.yandex.ru/watch/83230288" style="position:absolute; left:-9999px;" alt="" /></div></no
# <!-- /Yandex.Metrika counter -->
#
#
# </body>
#
# </html>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="ru-ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="KBTU - Лучший Технический университет Казахстана - образование на английском языке в Алматы - диплом международного уровня - техническое образование в Алматы - Тел. ☎ +7( 727) 357 42 51" name="description"/>
# <meta content="Joomla! - Open Source Content Management" name="generator"/>
# <title>Казахстанско-Британский технический университет | КБТУ</title>
# <link href="/ru/?format=feed&amp;type=rss" rel="alternate" title="Казахстанско-Британский технический университет | КБТУ" type="application/rss+xml"/>
# <link href="/ru/?format=feed&amp;type=atom" rel="alternate" title="Казахстанско-Британский технический университет | КБТУ" type="application/atom+xml"/>
# <link href="https://kbtu.edu.kz/kz/" hreflang="kz-KZ" rel="alternate"/>
# <link href="https://kbtu.edu.kz/ru/" hreflang="ru-RU" rel="alternate"/>
# <link href="https://kbtu.edu.kz/en/" hreflang="en-GB" rel="alternate"/>
# <link href="/media/system/images/favicon.png" rel="shortcut icon" type="image/png"/>
# <link as="style" href="//fonts.googleapis.com/css?family=Open+Sans:300,300italic,regular,italic,600,600italic,700,700italic,800,800italic&amp;amp;subset=cyrillic-ext,latin&amp;display=swap" media="all" onload="this.rel='stylesheet'" rel="stylesheet"/>
# <link href="/media/system/css/joomla-fontawesome.min.css?c89eb5" rel="lazy-stylesheet"/><noscript><link href="/media/system/css/joomla-fontawesome.min.css?c89eb5" rel="stylesheet"/></noscript>
# <link crossorigin="anonymous" href="https://fonts.googleapis.com/css2?family=Fira+Sans:wght@100;300;400;700&amp;display=swap" rel="lazy-stylesheet"/><noscript><link href="https://fonts.googleapis.com/css2?family=Fira+Sans:wght@100;300;400;700&amp;display=swap" rel="stylesheet"/></noscript>
# <link href="/media/templates/site/cassiopeia/css/template.css?c89eb5" rel="stylesheet"/>
# <link href="/media/templates/site/cassiopeia/css/global/colors_standard.min.css?c89eb5" rel="stylesheet"/>
# <link href="/media/templates/site/cassiopeia/css/bootstrap.min.css?c89eb5" rel="stylesheet"/>
# <link href="/media/templates/site/cassiopeia/css/personal.css?c89eb5" rel="stylesheet"/>
# <link href="/media/mod_articles/css/mod-articles.min.css?c89eb5" rel="stylesheet"/>
# <link href="/media/mod_languages/css/template.min.css?c89eb5" rel="stylesheet"/>
# <link href="/media/templates/site/cassiopeia/css/vendor/joomla-custom-elements/joomla-alert.min.css?0.2.0" rel="stylesheet"/>
# <link href="/media/com_sliderck/assets/swiper.css?ver=2.4.4" rel="stylesheet"/>
# <style>:root {
# 		--hue: 214;
# 		--template-bg-light: #f0f4fb;
# 		--template-text-dark: #495057;
# 		--template-text-light: #ffffff;
# 		--template-link-color: var(--link-color);
# 		--template-special-color: #001B4C;
# 		--cassiopeia-font-family-body: "Fira Sans", sans-serif;
# 			--cassiopeia-font-family-headings: "Fira Sans", sans-serif;
# 			--cassiopeia-font-weight-normal: 400;
# 			--cassiopeia-font-weight-headings: 700;
# 	}</style>
# <style>#sliderck315 .swiper-img-cont { background-size: cover; }</style>
# <style>#sliderck314 .swiper-img-cont { background-size: cover; }</style>
# <style>#sliderck311 { height: 50px; }#sliderck311 .swiper-slide .swiper-img { height: 100% }#sliderck311 .swiper-img-cont { background-size: auto 100% }</style>
# <style>#sliderck316 { height: 50px; }#sliderck316 .swiper-slide .swiper-img { height: 100% }#sliderck316 .swiper-img-cont { background-size: auto 100% }</style>
# <script src="/media/vendor/jquery/js/jquery.min.js?3.7.1"></script>
# <script src="/media/legacy/js/jquery-noconflict.min.js?504da4"></script>
# <script src="/media/templates/site/cassiopeia/js/bootstrap.bundle.min.js?c89eb5"></script>
# <script src="/media/templates/site/cassiopeia/js/personal.js?c89eb5"></script>
# <script src="/media/mod_menu/js/menu.min.js?c89eb5" type="module"></script>
# <script class="joomla-script-options new" type="application/json">{"joomla.jtext":{"MOD_FINDER_SEARCH_VALUE":"Введите текст...","ERROR":"Ошибка","MESSAGE":"Сообщение","NOTICE":"Внимание","WARNING":"Предупреждение","JCLOSE":"Закрыть","JOK":"Ок","JOPEN":"Открыть"},"system.paths":{"root":"","rootFull":"https://kbtu.edu.kz/","base":"","baseFull":"https://kbtu.edu.kz/"},"csrf.token":"053e1d4632883d2054a7239848741cdb"}</script>
# <script src="/media/system/js/core.min.js?2cb912"></script>
# <script src="/media/templates/site/cassiopeia/js/template.min.js?c89eb5" type="module"></script>
# <script src="/media/com_finder/js/finder.min.js?5729ed" type="module"></script>
# <script src="/media/system/js/messages.min.js?9a4811" type="module"></script>
# <script src="/media/com_sliderck/assets/swiper.min.js?ver=2.4.4"></script>
# <script>jQuery(document).ready(function(){
# 	var sliderck315 = new Swiper('#sliderck315', {
# 		pagination: '.swiper-pagination',
# 		paginationClickable: true,
# 		setWrapperSize: true, // nécessaire pour garder les images centrées lors de la réduction de la fenêtre
# 		slidesPerView: '1',
# 		slidesPerGroup: 1,
# 		slidesPerColumn: 1,
# 		spaceBetween: 10,
# 		centeredSlides: false,
# 		initialSlide: 0,
# 		freeMode: 0,
# 		speed: 3000,
# 		autoplay: 8000,
# 		autoplayDisableOnInteraction: true,
# 		autoplayStopOnLast: 1,
# 		autoplayPauseOnOver: false,
# 		effect: 'slide',
# 		fade: {crossFade: true},
# 		loop: true,
# 		loopedSlides: 8,
# 		keyboardControl: 0,
# 		mousewheelControl: 0,
# 		a11y: true,
# 		paginationType: 'bullets', // 'bullets' or 'progress' or 'fraction' or 'custom'
# 		breakpoints: {
# 360: {
# 			slidesPerView: 1,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 1
# 		},
# 480: {
# 			slidesPerView: 1,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 1
# 		},
# 640: {
# 			slidesPerView: 3,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 30
# 		}},
#
# 		// direction: 'horizontal',
# 		// autoHeight: true, //enable auto height to use more with content in slides. Not for images
#
# 	});
#
# });
# </script>
# <script>jQuery(document).ready(function(){
# 	var sliderck314 = new Swiper('#sliderck314', {
# 		pagination: '.swiper-pagination',
# 		paginationClickable: true,
# 		setWrapperSize: true, // nécessaire pour garder les images centrées lors de la réduction de la fenêtre
# 		slidesPerView: '3',
# 		slidesPerGroup: 1,
# 		slidesPerColumn: 1,
# 		spaceBetween: 1,
# 		centeredSlides: false,
# 		initialSlide: 0,
# 		freeMode: 0,
# 		speed: 3000,
# 		autoplay: 1000,
# 		autoplayDisableOnInteraction: true,
# 		autoplayStopOnLast: 1,
# 		autoplayPauseOnOver: false,
# 		effect: 'slide',
# 		fade: {crossFade: true},
# 		loop: true,
# 		loopedSlides: 8,
# 		keyboardControl: 0,
# 		mousewheelControl: 0,
# 		a11y: true,
# 		paginationType: 'bullets', // 'bullets' or 'progress' or 'fraction' or 'custom'
# 		breakpoints: {
# 360: {
# 			slidesPerView: 1,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 1
# 		},
# 480: {
# 			slidesPerView: 1,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 1
# 		},
# 640: {
# 			slidesPerView: 3,
# 			slidesPerGroup: 1,
# 			slidesPerColumn: 1,
# 			spaceBetween: 30
# 		}},
#
# 		// direction: 'horizontal',
# 		// autoHeight: true, //enable auto height to use more with content in slides. Not for images
#
# 	});
#
# });
# </script>
# <script>jQuery(document).ready(function(){
# 	var sliderck311 = new Swiper('#sliderck311', {
#
# 		setWrapperSize: true, // nécessaire pour garder les images centrées lors de la réduction de la fenêtre
# 		slidesPerView: 'auto',
# 		slidesPerGroup: 1,
# 		slidesPerColumn: 1,
# 		spaceBetween: 30,
# 		centeredSlides: true,
# 		initialSlide: 0,
# 		freeMode: 0,
# 		speed: 3000,
# 		autoplay: 1,
# 		autoplayDisableOnInteraction: true,
# 		autoplayStopOnLast: 1,
# 		autoplayPauseOnOver: false,
# 		effect: 'slide',
# 		fade: {crossFade: true},
# 		loop: true,
# 		loopedSlides: 78,
# 		keyboardControl: 0,
# 		mousewheelControl: 0,
# 		a11y: true,
# 		paginationType: 'none', // 'bullets' or 'progress' or 'fraction' or 'custom'
#
# 		// direction: 'horizontal',
# 		// autoHeight: true, //enable auto height to use more with content in slides. Not for images
#
# 	});
#
# });
# </script>
# <script>jQuery(document).ready(function(){
# 	var sliderck316 = new Swiper('#sliderck316', {
#
# 		setWrapperSize: true, // nécessaire pour garder les images centrées lors de la réduction de la fenêtre
# 		slidesPerView: 'auto',
# 		slidesPerGroup: 1,
# 		slidesPerColumn: 1,
# 		spaceBetween: 30,
# 		centeredSlides: true,
# 		initialSlide: 0,
# 		freeMode: 0,
# 		speed: 3000,
# 		autoplay: 1,
# 		autoplayDisableOnInteraction: true,
# 		autoplayStopOnLast: 1,
# 		autoplayPauseOnOver: false,
# 		effect: 'slide',
# 		fade: {crossFade: true},
# 		loop: true,
# 		loopedSlides: 7,
# 		keyboardControl: 0,
# 		mousewheelControl: 0,
# 		a11y: true,
# 		paginationType: 'none', // 'bullets' or 'progress' or 'fraction' or 'custom'
#
# 		// direction: 'horizontal',
# 		// autoHeight: true, //enable auto height to use more with content in slides. Not for images
#
# 	});
#
# });
# </script>
# <link href="https://kbtu.edu.kz/kz/" hreflang="x-default" rel="alternate"/>
# </head>
# <body class="site com_content wrapper-static view-featured no-layout no-task itemid-1587">
# <div class="overlay"></div>
# <header class="header container-header full-width position-sticky sticky-top" id="header">
# <div class="container">
# <div class="row">
# <div class="grid-child container-below-top">
# <div class="moduletable">
# <form action="/ru/rezultaty-poiska" class="mod-finder js-finder-searchform form-search" method="get" role="search">
# <label class="visually-hidden finder" for="mod-finder-searchword295">Поиск</label><div class="mod-finder__search input-group"><input class="js-finder-search-query form-control" id="mod-finder-searchword295" name="q" placeholder="Введите текст..." type="text" value=""/><button class="btn btn-primary" type="submit"><span aria-hidden="true" class="icon-search icon-white"></span> Поиск</button></div>
# </form>
# </div>
# <div class="mod-languages">
# <p class="visually-hidden" id="language_picker_des_300">Выберите язык</p>
# <ul aria-labelledby="language_picker_des_300" class="mod-languages__list lang-inline">
# <li>
# <a href="/kz/">
#                                             KZ                                    </a>
# </li>
# <li class="lang-active">
# <a aria-current="true" href="https://kbtu.edu.kz/ru/">
#                                             RU                                    </a>
# </li>
# <li>
# <a href="/en/">
#                                             EN                                    </a>
# </li>
# </ul>
# </div>
# </div>
# <div class
></li><li class="nav-item item-1496"><a href="/ru/studentam/antiterror-rus">Anti-terror</a></li></ul></div></li><li class="nav-item item-105"><a href="/ru/shkoly">Школы</a></li><li class="nav-item item-1691"><a href="/ru/internatsionalizatsiya">Интернационализация</a></li><li class="nav-item item-967 deeper parent-icon"><a href="#">Наука</a><div class="sub-menu-block"><ul class="mod-menu__sub list-unstyled sub-menu"><li class="nav-item item-966 parent-icon"><a class="akernsd" href="/ru/nauka/o-nauke">О науке</a></li><li class="nav-item item-968"><a href="/ru/nauka/ao-institut-khimicheskikh-nauk-imeni-a-b-bekturova">АО «Институт химических наук имени А.Б. Бектурова»</a></li><li class="nav-item item-969"><a href="/ru/nauka/ao-institut-topliva-kataliza-i-elektrokhimii-im-d-v-sokolskogo">АО «Институт топлива, катализа и электрохимии им. Д.В.Сокольского»</a></li><li class="nav-item item-970"><a href="/ru/nauka/too-institut-inzhiniringa-i-informatsionnykh-tekhnologij-kbtu">ТОО «Институт инжиниринга и информационных технологий КБТУ» ...
# </div>
# <ul class="social_icons">
# <li class="icon-telegram"><a href="https://t.me/kbtuadmission"><i class="fa fa-telegram"></i></a></li>
# <li class="icon-facebook"><a href="https://www.facebook.com/share/16h9YWYh4a/?mibextid=wwXIfr"><i class="fa-brands fa-facebook"></i></a></li>
# <li class="icon-youtube"><a href="https://youtube.com/@kbtuofficialchannel?si=2owNsMTSAeAFez-G"><i class="fa-brands fa-square-youtube"></i></a></li>
# <li class="icon-tiktok"><a href="https://www.tiktok.com/@kbtu_official?_t=ZM-8xMCIALO88c&amp;_r=1"><i class="fa-brands fa-tiktok"></i></a></li>
# <li class="icon-instagram"><a href="https://www.instagram.com/kbtu_official?igsh=MXZjNHlxamU3bGYyYQ%3D%3D&amp;utm_source=qr"><i class="fa fa-instagram"></i></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="site-grid">
# <div class="container-banner">
# <div class="banner no-card block_main_slider">
# <div class="swiper-container swiper-layout-over block_main_slider" data-effect="slide" dir="ltr" id="sliderck315">
# <div class="swiper-wrapper">
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/event_19022026_rus.png')">
# <img alt="" class="swiper-img" src="/images/event_19022026_rus.png">
# </img></figure>
# <a aria-label="" class="swiper-link" href="/activity/5052-v-kbtu-projdet-pervaya-v-tsentralnoj-azii-nauchnaya-konferentsiya-po-issledovaniyu-videoigr-digra-central-asia-conference"></a> </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/banner_18022026_rus.jpg')">
# <img alt="" class="swiper-img" src="/images/banner_18022026_rus.jpg"/>
# </figure>
# <a aria-label="" class="swiper-link" href="/activity/5047-mezhdunarodnaya-molodezhnaya-nauchno-prakticheskaya-konferentsiya"></a> </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/iwcf_banner_12112025_rus.png')">
# <img alt="" class="swiper-img" src="/images/iwcf_banner_12112025_rus.png"/>
# </figure>
# <a aria-label="" class="swiper-link" href="/akademiya-korporativnogo-obrazovaniya/nepreryvnoe-obrazovanie/4911-mezhdunarodnaya-sertifikatsiya-iwcf"></a> </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/pr_banner_2025_3_rus.png')">
# <img alt="" class="swiper-img" src="/images/pr_banner_2025_3_rus.png"/>
# </figure>
# <a aria-label="" class="swiper-link" href="/priemnaya-komissiya-kbtu"></a> </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/main_banner_bp_ru.jpg')">
# <img alt="" class="swiper-img" src="/images/main_banner_bp_ru.jpg"/>
# </figure>
# <a aria-label="" class="swiper-link" href="/akademiya-korporativnogo-obrazovaniya"></a> </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/main_banner_new_2025_ru.jpg')">
# <img alt="" class="swiper-img" src="/images/main_banner_new_2025_ru.jpg"/>
# </figure>
# <a aria-label="" class="swiper-link" href="/novye-obrazovatelnye-programmy-kbtu-2025"></a> </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/UNIVERSITY_OF_LONDON_RUS.jpg')">
# <img alt="" class="swiper-img" src="/images/UNIVERSITY_OF_LONDON_RUS.jpg"/>
# </figure>
# <a aria-label="" class="swiper-link" href="https://gd.kbtu.kz/" target="_blank"></a> </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/GRI_baner_RU.png')">
# <img alt="" class="swiper-img" src="/images/GRI_baner_RU.png"/>
# </figure>
# <a aria-label="" class="swiper-link" href="/ob-universitete/tsentr-esg-kompetentsij-kbtu"></a> </div>
# </div>
# <div class="swiper-pagination"></div>
# </div>
# </div>
# </div>
# <div class="grid-child container-top-a">
# <div class="top-a no-card">
# <div class="mod-custom custom" id="mod-custom309">
# <div class="row">
# <div class="col-6 col-md-3 p-2">
# <div class="statistic_block"><span class="title">Год основания</span><span class="count count_1">2001</span></div>
# </div>
# <div class="col-6 col-md-3 p-2">
# <div class="statistic_block"><span class="title">Обучающихся</span> <span class="count count_2">7746</span></div>
# </div>
# <div class="col-6 col-md-3 p-2">
# <div class="statistic_block"><span class="title">Трудоустройство</span> <span class="count count_3">98%</span></div>
# </div>
# <div class="col-6 col-md-3 p-2">
# <div class="statistic_block"><span class="title">Школ</span> <span class="count count_4">10</span></div>
# </div>
# </div></div>
# </div>
# </div>
# <div class="grid-child container-top-b">
# <div class="top-b no-card">
# <div class="mod-custom custom" id="mod-custom310">
# <div class="row">
# <div class="col-sm-12 col-md-4 p-2">
# <div class="learn_main_block">
# <div class="main_img"><img class="float-none" src="/images/learn_img.jpg"/></div>
# <div class="learn_block"><a href="/priemnaya-komissiya-bakalavriat">
# <div class="title">БАКАЛАВРИАТ</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# </div>
# <div class="col-sm-12 col-md-8 p-0">
# <div class="row">
# <div class="col-12 p-2">
# <div class="learn_block"><a href="/priemnaya-komissiya-magistratura">
# <div class="title">Магистратура</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# <div class="col-12 p-2">
# <div class="learn_block"><a href="/priemnaya-komissiya-doctorantura">
# <div class="title">Докторантура</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# <div class="col-12 p-2">
# <div class="learn_block"><a href="/akademiya-korporativnogo-obrazovaniya">
# <div class="title">Академия корпоративного образования</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# <div class="col-12 p-2">
# <div class="learn_block"><a href="/internatsionalizatsiya/priem-inostrannykh-abiturientov">
# <div class="title">International Admission</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# <div class="col-12 p-2">
# <div class="learn_block"><a href="https://gd.kbtu.kz/">
# <div class="title">Graduate Diploma</div>
# <div class="link">Узнать подробно</div>
# </a></div>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div>
# <div class="grid-child container-component">
# <div aria-live="polite" id="system-message-container"></div>
# <main>
# <div class="blog-featured">
# </div>
# </main>
# </div>
# <div class="grid-child container-bottom-a">
# <div class="bottom-a card block_events">
# <h1 class="card-header">События</h1> <div class="card-body">
# <ul class="mod-articles-items mod-list">
# <li>
# <article class="mod-articles-item" itemscope="" itemtype="https://schema.org/Article">
# <div class="mod-articles-item-content">
# <h4 class="mod-articles-title" itemprop="name">
# <a class="mod-articles-link" href="/ru/activity/5052-v-kbtu-projdet-pervaya-v-tsentralnoj-azii-nauchnaya-konferentsiya-po-issledovaniyu-videoigr-digra-central-asia-conference" itemprop="url"><span><div>В КБТУ пройдет первая в Центральной Азии научная конференция по исследованию видеоигр DiGRA Central Asia Conference</div></span></a> </h4>
# <figure class="mod-articles-image item-image">
# <img height="550" loading="lazy" src="/images/event_19022026_rus.png" width="1320"/> </figure>
# <p>21 февраля 2026 года в Казахстанско-Британском Техническом Университете (КБТУ) состоится первая в</p>...
#
#                                             </div>
# </article>
# </li>
# <li>
# <article class="mod-articles-item" itemscope="" itemtype="https://schema.org/Article">
# <div class="mod-articles-item-content">
# <h4 class="mod-articles-title" itemprop="name">
# <a class="mod-articles-link" href="/ru/activity/5050-vysshee-obrazovanie-i-nauka-god-tsifrovizatsii-i-iskusstvennogo-intellekta" itemprop="url"><span><div>Высшее образование и наука: год цифровизации и искусственного интеллекта</div></span></a> </h4>
# <figure class="mod-articles-image item-image">
# <img height="1000" loading="lazy" src="/images/event_16022026.jpg" width="1500"/> </figure>
# <p>12–13 февраля 2026 года в Казахском национальном исследовательском техническом университете имени К. И.</p>...
#
#                                             </div>
# </article>
# </li>
# <li>
# <article class="mod-articles-item" itemscope="" itemtype="https://schema.org/Article">
# <div class="mod-articles-item-content">
# <h4 class="mod-articles-title" itemprop="name">
# <a class="mod-articles-link" href="/ru/activity/5047-mezhdunarodnaya-molodezhnaya-nauchno-prakticheskaya-konferentsiya" itemprop="url"><span><div>Международная молодежная научно-практическая конференция</div></span></a> </h4>
# <figure class="mod-articles-image item-image">
# <img height="550" loading="lazy" src="/images/banner_18022026_rus.jpg" width="1320"/> </figure>
# <p>9–10 апреля 2026 года в КБТУ по инициативе Школы энергетики и нефтегазовой индустрии состоится</p>...
#
#                                             </div>
# </article>
# </li>
# <li>
# <article class="mod-articles-item" itemscope="" itemtype="https://schema.org/Article">
# <div class="mod-articles-item-content">
# <h4 class="mod-articles-title" itemprop="name">
# <a class="mod-articles-link" href="/ru/activity/5016-luchshij-prepodavatel-vuza-2025" itemprop="url"><span><div>Лучший преподаватель вуза – 2025</div></span></a> </h4>
# <figure class="mod-articles-image item-image">
# <img height="3240" loading="lazy" src="/images/event_18112025.jpg" width="3240"/> </figure>
# <p>Казахстанко-Британский технический университет сообщает о публикации итогов первого этапа</p>...
#
#                                             </div>
# </article>
# </li>
# <li>
# <article class="mod-articles-item" itemscope="" itemtype="https://schema.org/Article">
# <div class="mod-articles-item-content">
# <h4 class="mod-articles-title" itemprop="name">
# <a class="mod-articles-link" href="/ru/activity/4962-akademicheskaya-mobilnost-v-yuzhnuyu-koreyu" itemprop="url"><span><div>Академическая мобильность в Южную Корею </div></span></a> </h4>
# <figure class="mod-articles-image item-image">
# <img height="1280" loading="lazy" src="/images/photo_5332293445668173331_y.jpg" width="1024"/> </figure>
# <p>Сообщаем, что южнокорейские университеты Gwangju Institute of Science and Technology (GIST) и</p>...
#
#                                             </div>
# </article>
# </li>
# </ul>
# </div>
# </div>
# <div class="mod-custom custom" id="mod-custom96">
# <p><a class="btn btn_category" href="/activity">ВСЕ СОБЫТИЯ</a></p></div>
# </div>
# <div class="grid-child container-bottom-b">
# <div class="bottom-b card block_main_prof_man">
# <h3 class="card-header">Профессорско-преподавательский состав</h3> <div class="card-body">
# <div class="swiper-container swiper-layout-over block_main_prof_man" data-effect="slide" dir="ltr" id="sliderck314">
# <div class="swiper-wrapper">
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/PAUL_DAVIS.png')">
# <img alt="Дэвис Пол Джеймс &lt;span class='prof'&gt;Профессор&lt;/span&gt;" class="swiper-img" src="/images/PAUL_DAVIS.png">
# </img></figure>
# <div class="swiper-caption">
# <div class="swiper-title">
# 					Дэвис Пол Джеймс <span class="prof">Профессор</span> </div>
# <div class="swiper-desc">
# 					Бизнес Школа				</div>
# </div>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/PAKIZAR_S_SHAMOI.png')">
# <img alt="Шамои Пакизар Сулгадиновна &lt;span class='prof'&gt;Профессор&lt;/span&gt;" class="swiper-img" src="/images/PAKIZAR_S_SHAMOI.png">
# </img></figure>
# <div class="swiper-caption">
# <div class="swiper-title">
# 					Шамои Пакизар Сулгадиновна <span class="prof">Профессор</span> </div>
# <div class="swiper-desc">
# 					Школа информационных технологий и инженерии				</div>
# </div>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/laumunin_chokan.jpg')">
# <img alt="Лаумулин Чокан Турарович&lt;span class='prof'&gt;Профессор&lt;/span&gt;" class="swiper-img" src="/images/laumunin_chokan.jpg">
# </img></figure>
# <div class="swiper-caption">
# <div class="swiper-title">
# 					Лаумулин Чокан Турарович<span class="prof">Профессор</span> </div>
# <div class="swiper-desc">
# 					Школа естественных и социальных наук				</div>
# </div>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/turgazinov_ilas.jpg')">
# <img alt="Тургазинов Ильяс Казбекұлы&lt;span class='prof'&gt;Ассистент-профессор&lt;/span&gt;" class="swiper-img" src="/images/turgazinov_ilas.jpg">
# </img></figure>
# <div class="swiper-caption">
# <div class="swiper-title">
# 					Тургазинов Ильяс Казбекұлы<span class="prof">Ассистент-профессор</span> </div>
# <div class="swiper-desc">
# 					Школа энергетики и нефтегазовой индустрии				</div>
# </div>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/ZHAMAL_S_TULEMISSOVA.jpg')">
# <img alt="Тулемисова Жамал Сериковна&lt;span class='prof'&gt;Ассоциированный профессор&lt;/span&gt;" class="swiper-img" src="/images/ZHAMAL_S_TULEMISSOVA.jpg">
# </img></figure>
# <div class="swiper-caption">
# <div class="swiper-title">
# 					Тулемисова Жамал Сериковна<span class="prof">Ассоциированный профессор</span> </div>
# <div class="swiper-desc">
# 					Школа геологии				</div>
# </div>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/ASKAR_S_DZHUMADILDAYEV.png')">
# <img alt="Джумадильдаев Аскар Серкулович&lt;span class='prof'&gt;Профессор&lt;/span&gt;" class="swiper-img" src="/images/ASKAR_S_DZHUMADILDAYEV.png">
# </img></figure>
# <div class="swiper-caption">
# <div class="swiper-title">
# 					Джумадильдаев Аскар Серкулович<span class="prof">Профессор</span> </div>
# <div class="swiper-desc">
# 					Школа прикладной математики				</div>
# </div>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/KAIR_KH_NUSSUPOV.png')">
# <img alt="Нусупов Каир Хамзаевич&lt;span class='prof'&gt;Профессор&lt;/span&gt;" class="swiper-img" src="/images/KAIR_KH_NUSSUPOV.png"/>
# </figure>
# <div class="swiper-caption">
# <div class="swiper-title">
# 					Нусупов Каир Хамзаевич<span class="prof">Профессор</span> </div>
# <div class="swiper-desc">
# 					Школа материаловедения и зеленых технологий				</div>
# </div>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/aidarova_saule.jpg')">
# <img alt="Айдарова Сауле Байляровна&lt;span class='prof'&gt;Профессор&lt;/span&gt;" class="swiper-img" src="/images/aidarova_saule.jpg"/>
# </figure>
# <div class="swiper-caption">
# <div class="swiper-title">
# 					Айдарова Сауле Байляровна<span class="prof">Профессор</span> </div>
# <div class="swiper-desc">
# 					Школа материаловедения и зеленых технологий				</div>
# </div>
# </div>
# </div>
# <div class="swiper-pagination"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-child container-bottom-c">
# <div class="bottom-c card block_news">
# <h1 class="card-header">Новости</h1> <div class="card-body">
# <ul class="mod-articles-items mod-list">
# <li>
# <article class="mod-articles-item" itemscope="" itemtype="https://schema.org/Article">
# <div class="mod-articles-item-content">
# <h4 class="mod-articles-title" itemprop="name">
# <a class="mod-articles-link" href="/ru/novosty/5043-12-e-mesto-iz-34-komand-studenty-kbtu-uspeshno-vystupili-na-shell-eco-marathon-2026-v-katare" itemprop="url"><span><div>12-е место из 34 команд: студенты КБТУ  успешно выступили на Shell Eco-Marathon 2026 в Катаре</div></span></a> </h4>
# <dl class="list-unstyled">
# <dt class="article-info-term">
# <span class="visually-hidden">
#                                         Информация о материале                                    </span>
# </dt>
# <dd class="mod-articles-date">
# <span aria-hidden="true" class="icon-calendar icon-fw"></span>                                        2026-02-06 17:37:42                                    </dd>
# </dl>
# <figure class="mod-articles-image item-image">
# <img height="853" loading="lazy" src="/images/new_06022026.jpg" width="1280"/> </figure>
# <p class="readmore">
# <a aria-label="Подробнее: 12-е место из 34 команд: студенты КБТУ  успешно выступили на Shell Eco-Marathon 2026 в Катаре" href="/ru/novosty/5043-12-e-mesto-iz-34-komand-studenty-kbtu-uspeshno-vystupili-na-shell-eco-marathon-2026-v-katare">
#             Узнать подробнее        </a>
# </p>
# </div>
# </article>
# </li>
# <li>
# <article class="mod-articles-item" itemscope="" itemtype="https://schema.org/Article">
# <div class="mod-articles-item-content">
# <h4 class="mod-articles-title" itemprop="name">
# <a class="mod-articles-link" href="/ru/novosty/5037-delegatsiya-kbtu-provela-vstrechi-s-sanda-university-i-wuchuang-group" itemprop="url"><span><div>Делегация КБТУ провела встречи с Sanda University и Wuchuang Group</div></span></a> </h4>
# <dl class="list-unstyled">
# <dt class="article-info-term">
# <span class="visually-hidden">
#                                         Информация о материале                                    </span>
# </dt>
# <dd class="mod-articles-date">
# <span aria-hidden="true" class="icon-calendar icon-fw"></span>                                        2025-12-31 09:52:03                                    </dd>
# </dl>
# <figure class="mod-articles-image item-image">
# <img height="960" loading="lazy" src="/images/photo_5377783471528415000_y.jpg" width="1280"/> </figure>
# <p class="readmore">
# <a aria-label="Подробнее: Делегация КБТУ провела встречи с Sanda University и Wuchuang Group" href="/ru/novosty/5037-delegatsiya-kbtu-provela-vstrechi-s-sanda-university-i-wuchuang-group">
#             Узнать подробнее        </a>
# </p>
# </div>
# </article>
# </li>
# <li>
# <article class="mod-articles-item" itemscope="" itemtype="https://schema.org/Article">
# <div class="mod-articles-item-content">
# <h4 class="mod-articles-title" itemprop="name">
# <a class="mod-articles-link" href="/ru/novosty/5034-delegatsiya-kbtu-provela-rabochie-vstrechi-v-shankhajskom-universitete-tszyaotun" itemprop="url"><span><div>Делегация КБТУ провела рабочие встречи в Шанхайском университете Цзяотун</div></span></a> </h4>
# <dl class="list-unstyled">
# <dt class="article-info-term">
# <span class="visually-hidden">
#                                         Информация о материале                                    </span>
# </dt>
# <dd class="mod-articles-date">
# <span aria-hidden="true" class="icon-calendar icon-fw"></span>                                        2025-12-30 15:40:19                                    </dd>
# </dl>
# <figure class="mod-articles-image item-image">
# <img height="960" loading="lazy" src="/images/new_3012025.jpg" width="1280"/> </figure>
# <p class="readmore">
# <a aria-label="Подробнее: Делегация КБТУ провела рабочие встречи в Шанхайском университете Цзяотун" href="/ru/novosty/5034-delegatsiya-kbtu-provela-rabochie-vstrechi-v-shankhajskom-universitete-tszyaotun">
#             Узнать подробнее        </a>
# </p>
# </div>
# </article>
# </li>
# <li>
# <article class="mod-articles-item" itemscope="" itemtype="https://schema.org/Article">
# <div class="mod-articles-item-content">
# <h4 class="mod-articles-title" itemprop="name">
# <a class="mod-articles-link" href="/ru/novosty/5032-konkurs-vakantnykh-grantov-kbtu-2025-2026-rus" itemprop="url"><span><div>КОНКУРС ВАКАНТНЫХ ГРАНТОВ КБТУ</div></span></a> </h4>
# <dl class="list-unstyled">
# <dt class="article-info-term">
# <span class="visually-hidden">
#                                         Информация о материале                                    </span>
# </dt>
# <dd class="mod-articles-date">
# <span aria-hidden="true" class="icon-calendar icon-fw"></span>                                        2025-12-11 15:57:25                                    </dd>
# </dl>
# <figure class="mod-articles-image item-image">
# <img height="640" loading="lazy" src="/images/new_17062024_3_rus.jpg" width="1320"/> </figure>
# <p class="readmore">
# <a aria-label="Подробнее: КОНКУРС ВАКАНТНЫХ ГРАНТОВ КБТУ" href="/ru/novosty/5032-konkurs-vakantnykh-grantov-kbtu-2025-2026-rus">
#             Узнать подробнее        </a>
# </p>
# </div>
# </article>
# </li>
# </ul>
# </div>
# </div>
# <div class="mod-custom custom" id="mod-custom318">
# <p><a class="btn btn_category" href="/novosty">ВСЕ НОВОСТИ</a></p></div>
# </div>
# <div class="grid-child container-bottom-d">
# <div class="bottom-d card block_own_partners">
# <h3 class="card-header">Наши партнеры</h3> <div class="card-body">
# <div class="swiper-container swiper-layout-over block_own_partners" data-effect="slide" dir="ltr" id="sliderck311">
# <div class="swiper-wrapper">
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/adal_logo.png')">
# <img alt="" class="swiper-img" src="/images/adal_logo.png">
# </img></figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/su_logo.png')">
# <img alt="" class="swiper-img" src="/images/su_logo.png">
# </img></figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part1-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part1-min.png">
# </img></figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part2-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part2-min.png">
# </img></figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part3-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part3-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part4-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part4-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part5-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part5-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part6-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part6-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part7-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part7-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part8-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part8-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part9-min.jpeg')">
# <img alt="" class="swiper-img" src="/images/partner/part9-min.jpeg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part10-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part10-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part11-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part11-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part12-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part12-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part13-min.jpeg')">
# <img alt="" class="swiper-img" src="/images/partner/part13-min.jpeg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part14-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part14-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part15-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part15-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part16-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part16-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part17-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part17-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part18-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part18-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part19-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part19-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part20-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part20-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part21-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part21-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part22-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part22-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part24-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part24-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part25-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part25-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part26-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part26-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part27-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part27-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part28-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part28-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part29-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part29-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part30-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part30-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part31-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part31-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part32-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part32-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part33-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part33-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part34-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part34-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part35-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part35-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part36-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part36-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part37-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part37-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part38-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part38-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part40-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part40-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part41-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part41-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part44-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part44-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part46-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part46-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part47-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part47-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part48-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part48-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part49-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part49-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part50-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part50-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part51-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part51-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part52-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part52-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part53-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part53-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part54-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part54-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part55-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part55-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part56-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part56-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part57-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part57-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part59-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part59-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part60-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part60-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part61-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part61-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part62-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part62-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part63-min.jpg')">
# <img alt="" class="swiper-img" src="/images/partner/part63-min.jpg"/>
# </figure>
# </div>
# <div class="swiper-slide">
# <figure class="swiper-img-cont" style="background-image:url('/images/partner/part64-min.png')">
# <img alt="" class="swiper-img" src="/images/partner/part64-min.png"/>
# </figure>
# </div>
# <div class="swiper-slide">
# ...
# <div class="big_phone">8 727 357 42 42</div>
# <div class="address">Республика Казахстан, 050000, Алматы, ул. Толе би, 59</div>
# <div class="email"><a href="mailto:kense@kbtu.kz">kense@kbtu.kz</a></div>
# <div class="email"><a href="mailto:helpdesk@kbtu.kz">helpdesk@kbtu.kz</a></div>
# </div>
# <div class="col-md-3 col-12">
# <div class="title">Образование</div>
# <div class="other_data"><a href="/priemnaya-komissiya-bakalavriat">Бакалавриат</a></div>
# <div class="other_data"><a href="/priemnaya-komissiya-magistratura">Магистратура</a></div>
# <div class="other_data"><a href="/priemnaya-komissiya-doctorantura">Докторантура</a></div>
# <div class="other_data"><a href="/akademiya-korporativnogo-obrazovaniya">Академия корпоративного образования</a></div>
# <div class="other_data"><a href="/internatsionalizatsiya/priem-inostrannykh-abiturientov">International admission</a></div>
# </div>
# <div class="col-md-3 col-12">
# <div class="title">Приемная комиссия</div>
# <div class="phone">+7 (727) 357 42 51</div>
# <div class="email"><a href="mailto:admission@kbtu.kz">admission@kbtu.kz</a></div>
# </div>
# <div class="col-md-3 col-12">
# <div class="title">Полезные ссылки</div>
# <div class="other_data"><a href="/vacancy">Вакансии</a></div>
# <div class="other_data"><a href="/zakupki">Закупки</a></div>
# </div>
# </div>
# <div class="row m-0 mt-4">
# <div class="col-12 text-center">
# <p class="noanimate m-0 other_data">Любое использование материалов допускается только при наличии гиперссылки на <span style="text-decoration: underline;"><a href="https://kbtu.edu.kz/"><strong>https://kbtu.edu.kz</strong></a></span></p>
# </div>
# </div></div>
# </div>
# </div>
# </footer>
# <!-- -->
# <script>
#
# document.addEventListener("DOMContentLoaded", function () {
#
# /*
#
#     document.getElementById("form_ako").addEventListener("submit", async function (e) {
#         e.preventDefault(); // Останавливаем отправку формы
#
#         // Получаем значение уникального номера из формы
#         const certNumber = document.querySelector("input[name='certNumber']").value;
#
#         // Запрос к вашему API
#         const response = await fetch("https://script.google.com/macros/s/AKfycbyq2s77bKopALN18Oa-DLZNpOxdDbfoZOWs_7xocYobAVVBVnJvPX1bmmu6-RRGyO0ziA/exec" + certNumber);
#         const result = await response.json();
#
#         // Показываем результат
#         const resultDiv = document.getElementById("result");
#         if (result.error) {
#             resultDiv.innerHTML = `<p style="color: red;">${result.error}</p>`;
#         } else {
#             resultDiv.innerHTML = `
#                 <p>ФИО владельца: ${result.name}</p>
#                 <p>Дата получения: ${result.date}</p>
#                 <p>Курс: ${result.course}</p>
#                 <p>Комментарий: ${result.comment}</p>
#             `;
#         }
#
#         resultDiv.style.display = "block"; // Показываем результат
#     });
#
# */
#
# <!-- -->
#
#
#   // === Ваш публичный деплой GAS ===
#   const ACEV_BASE = "https://script.google.com/macros/s/AKfycbxxwAdjYRhANoLoXjOwb1KpXqJ1BkU3AdfiMEplCXRori17x-rh4e0Lb7qpXAaTgt5J/exec";
#
#   // === Определяем язык строго по вашему URL-формату ===
#   function acevGetLangFromUrl() {
#     const p = (location.pathname || "").toLowerCase();
#     if (p.startsWith("/en/")) return "en";
#     if (p.startsWith("/kz/")) return "kk";
#     return "ru"; // по умолчанию
#   }
#   const ACEV_LANG = acevGetLangFromUrl();
#
#   const ACEV_I18N = {
#     ru: {
#       btnOpen: "Верификация сертификата АКО",
#       modalTitle: "ID сертификата",
#       ariaCloseX: "Закрыть",
#       placeholder: "Например: DCP05-14-99999999",
#       hintPrefix: "Поддерживаются ID формата",
#       notRun: "Запрос ещё не выполнялся.",
#       btnSubmit: "Проверить",
#       btnClose: "Закрыть",
#       enterId: "Введите ID сертификата",
#       checking: "Проверяем…",
#       notFound: "Сертификат не найден",
#       requestError: "Ошибка запроса. Попробуйте позже или обратитесь в техподдержку.",
#       fio: "ФИО владельца",
#       course: "Курс",
#       dates: "Даты",
#       duration: "Продолжительность",
#       trainer: "Тренер",
#       id: "ID",
#       dash: "—"
#     },
#     en: {
#       btnOpen: "ACE Certificate Verification",
#       modalTitle: "Certificate ID",
#       ariaCloseX: "Close",
#       placeholder: "For example: DCP05-14-99999999",
#       hintPrefix: "Supported ID formats",
#       notRun: "No request has been made yet.",
#       btnSubmit: "Verify",
#       btnClose: "Close",
#       enterId: "Enter the certificate ID",
#       checking: "Verifying…",
#       notFound: "Certificate not found",
#       requestError: "Request error. Please try again later or contact support.",
#       fio: "Certificate holder",
#       course: "Course",
#       dates: "Dates",
#       duration: "Duration",
#       trainer: "Trainer",
#       id: "ID",
#       dash: "—"
#     },
#     kk: {
#       btnOpen: "КБА сертификатын тексеру",
#       modalTitle: "Сертификаттың ID нөмірі",
#       ariaCloseX: "Жабу",
#       placeholder: "Мысалы: DCP05-14-99999999",
#       hintPrefix: "Қолдау көрсетілетін ID форматтары",
#       notRun: "Сұраныс әлі орындалған жоқ.",
#       btnSubmit: "Тексеру",
#       btnClose: "Жабу",
#       enterId: "Сертификат ID енгізіңіз",
#       checking: "Тексерілуде…",
#       notFound: "Сертификат табылмады",
#       requestError: "Сұрау қатесі. Кейінірек қайталап көріңіз немесе техникалық қолдауға жүгініңіз.",
#       fio: "Иесінің аты-жөні",
#       course: "Курс",
#       dates: "Күндер",
#       duration: "Ұзақтығы",
#       trainer: "Тренер",
#       id: "ID",
#       dash: "—"
#     }
#   };
#
#   function acevT(key) {
#     return (ACEV_I18N[ACEV_LANG] && ACEV_I18N[ACEV_LANG][key])
#       ? ACEV_I18N[ACEV_LANG][key]
#       : (ACEV_I18N.ru[key] || key);
#   }
#
#   // DOM
#   const acevForm    = document.getElementById("acev-form");
#   const acevInput   = document.getElementById("acev-certNumber");
#   const acevBox     = document.getElementById("acev-result");
#   const acevBtn     = document.getElementById("acev-submit");
#   const acevBtnOpen = document.getElementById("acev-btn-open");
#   const acevTitle   = document.getElementById("acevModalLabel");
#   const acevHint    = document.getElementById("acev-hint");
#   const acevCloseX  = document.getElementById("acev-btn-close-x");
#   const acevClose   = document.getElementById("acev-btn-close");
#
#   // Локализация UI
#   if (acevBtnOpen) acevBtnOpen.textContent = acevT("btnOpen");
#   if (acevTitle)   acevTitle.textContent = acevT("modalTitle");
#   if (acevCloseX)  acevCloseX.setAttribute("aria-label", acevT("ariaCloseX"));
#   if (acevInput)   acevInput.placeholder = acevT("placeholder");
#   if (acevBtn)     acevBtn.textContent = acevT("btnSubmit");
#   if (acevClose)   acevClose.textContent = acevT("btnClose");
#   if (acevBox)     acevBox.textContent = acevT("notRun");
#
#   // Подсказка: сохраняем <code>, меняем вводную фразу
#   if (acevHint) {
#     const codes = Array.from(acevHint.querySelectorAll("code")).map(c => c.outerHTML).join(", ");
#     acevHint.innerHTML = `${acevEscapeHtml(acevT("hintPrefix"))} ${codes}`;
#   }
#
#   acevForm.addEventListener("submit", acevOnSubmit);
#
#   // Автозапуск по параметру: ?id=... или ?q=...
#   (function acevBootstrapFromQuery() {
#     const p = new URLSearchParams(location.search);
#     const q = p.get("id") || p.get("q");
#     if (q) {
#       acevInput.value = q;
#       setTimeout(() => acevForm.requestSubmit(), 0);
#     }
#   })();
#
#   async function acevOnSubmit(e) {
#     e.preventDefault();
#     const id = acevNormalizeId(acevInput.value);
#
#     acevBox.style.display = "block";
#     if (!id) {
#       acevBox.innerHTML = `<p class="text-danger mb-0">${acevEscapeHtml(acevT("enterId"))}</p>`;
#       return;
#     }
#
#     acevBtn.disabled = true;
#     acevInput.disabled = true;
#     acevBox.textContent = acevT("checking");
#
#     try {
#       // Если захотите локализовать ответы на стороне GAS — добавьте &lang=
#       // const url = ACEV_BASE + "?id=" + encodeURIComponent(id) + "&lang=" + encodeURIComponent(ACEV_LANG);
#       const url = ACEV_BASE + "?id=" + encodeURIComponent(id);
#
#       const resp = await fetch(url, { method: "GET", mode: "cors", cache: "no-store" });
#       if (!resp.ok) throw new Error("HTTP " + resp.status);
#       const res = await resp.json();
#
#       if (!res.ok) {
#         const msg = (res.message ? String(res.message) : "").trim();
#         const localized = (msg === "Сертификат не найден") ? acevT("notFound") : msg;
#         acevBox.innerHTML = `<p class="text-danger mb-0">${acevEscapeHtml(localized || acevT("notFound"))}</p>`;
#         return;
#       }
#
#       const d = res.data || {};
#       acevBox.innerHTML = [
#         acevRow(acevT("fio"), d.fio),
#         acevRow(acevT("course"), d.course),
#         acevRow(acevT("dates"), d.dates),
#         d.duration ? acevRow(acevT("duration"), d.duration) : "",
#         (d.trainer || d.trainerSign)
#           ? acevRow(
#               acevT("trainer"),
#               acevPrettifyTrainer(d.trainer) + (d.trainerSign ? ` (${d.trainerSign})` : "")
#             )
#           : "",
#         acevRow(acevT("id"), d.id),
#       ].filter(Boolean).join("");
#
#     } catch (err) {
#       console.error(err);
#       acevBox.innerHTML = `<p class="text-danger mb-0">${acevEscapeHtml(acevT("requestError"))}</p>`;
#     } finally {
#       acevBtn.disabled = false;
#       acevInput.disabled = false;
#     }
#   }
#
#   function acevPrettifyTrainer(s){
#     return String(s || "")
#       .split(/\s*\+\s*/g)
#       .map(v => v.trim())
#       .filter(Boolean)
#       .join(", ");
#   }
#
#   function acevRow(label, value) {
#     const v = value ? String(value) : acevT("dash");
#     return `<div class="mb-1"><b>${acevEscapeHtml(label)}:</b> ${acevEscapeHtml(v)}</div>`;
#   }
#
#   function acevNormalizeId(v) {
#     return String(v || "")
#       .replace(/[\u200B-\u200D\uFEFF]/g, "")
#       .replace(/\u00A0/g, " ")
#       .replace(/[–—−‒]/g, "-")
#       .trim();
#   }
#
#   function acevEscapeHtml(s) {
#     return String(s).replace(/[&<>"']/g, m => ({
#       "&":"&amp;", "<":"&lt;", ">":"&gt;", '"':"&quot;", "'":"&#39;"
#     }[m]));
#   }
#
# /*
#
#
#     // Публичный деплой GAS
#     const BASE = "https://script.google.com/macros/s/AKfycbxxwAdjYRhANoLoXjOwb1KpXqJ1BkU3AdfiMEplCXRori17x-rh4e0Lb7qpXAaTgt5J/exec";
#
#     const form  = document.getElementById("verify-form");
#     const input = document.getElementById("certNumber");
#     const box   = document.getElementById("result");
#     const btn   = document.getElementById("submit-btn");
#
#     form.addEventListener("submit", onSubmit);
#
#     // Автозапуск по параметру: verify.html?id=...
#     (function bootstrapFromQuery() {
#       const p = new URLSearchParams(location.search);
#       const q = p.get("id") || p.get("q");
#       if (q) {
#         input.value = q;
#         setTimeout(() => form.requestSubmit(), 0);
#       }
#     })();
#
#     async function onSubmit(e) {
#       e.preventDefault();
#       const id = normalizeId(input.value);
#
#       box.style.display = "block";
#       if (!id) {
#         box.innerHTML = `<p class="err">Введите ID сертификата</p>`;
#         return;
#       }
#
#       btn.disabled = true;
#       input.disabled = true;
#       box.textContent = "Проверяем…";
#
#       try {
#         const url = BASE + "?id=" + encodeURIComponent(id);
#         const resp = await fetch(url, { method: "GET", mode: "cors", cache: "no-store" });
#         if (!resp.ok) throw new Error("HTTP " + resp.status);
#         const res = await resp.json();
#
#         if (!res.ok) {
#           box.innerHTML = `<p class="err">${escapeHtml(res.message || "Сертификат не найден")}</p>`;
#           return;
#         }
#
#         const d = res.data || {};
#         // не показываем департамент и тип
#         box.innerHTML = [
#           row("ФИО владельца", d.fio),
#           row("Курс", d.course),
#           row("Даты", d.dates),
#           d.duration ? row("Продолжительность", d.duration) : "",
#           (d.trainer || d.trainerSign)
#   ? row(
#       "Тренер",
#       prettifyTrainer(d.trainer) + (d.trainerSign ? ` (${d.trainerSign})` : "")
#     )
#   : "",
#           row("ID", d.id),
#         ].filter(Boolean).join("");
#
#       } catch (err) {
#         console.error(err);
#         box.innerHTML = `<p class="err">Ошибка запроса. Попробуйте позже или обратитесь в техподдержку.</p>`;
#       } finally {
#         btn.disabled = false;
#         input.disabled = false;
#       }
#     }
# */
# function prettifyTrainer(s){
#   return String(s || "")
#     .split(/\s*\+\s*/g)
#     .map(v => v.trim())
#     .filter(Boolean)
#     .join(", ");
# }
#
# /*
#     function row(label, value) {
#       return `<div class="row"><b>${escapeHtml(label)}:</b> ${escapeHtml(value || "—")}</div>`;
#     }
#
#     // Нормализация ID: убираем невидимые символы, приводим разные тире к '-'
#     function normalizeId(v) {
#       return String(v || "")
#         .replace(/[\u200B-\u200D\uFEFF]/g, "") // zero-width
#         .replace(/\u00A0/g, " ")               // NBSP → space
#         .replace(/[–—−‒]/g, "-")               // все тире → '-'
#         .trim();
#     }
#
#     function escapeHtml(s) {
#       return String(s).replace(/[&<>"']/g, m => ({
#         "&":"&amp;", "<":"&lt;", ">":"&gt;", '"':"&quot;", "'":"&#39;"
#       }[m]));
#     }
#
# */
#
#
#
# });
#
# </script>
# <!-- -->
# <!-- Global Site Tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-77121331-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-77121331-1');
# </script>
# <!-- -->
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#    m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a
#    (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#    ym(37283880, "init", {
#         clickmap:true,
#         trackLinks:true,
#         accurateTrackBounce:true
#    });
#    </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/37283880" style="position:absolute; left:-9999px;"/></div>&lt;
# <!-- /Yandex.Metrika counter -->
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window, document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '402685197825792');
# fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=402685197825792&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <script type="text/javascript">
# var yaParams = {};
# var xhr = new XMLHttpRequest();
# xhr.open('GET', 'https://ip.up66.ru/', true);
# xhr.onload = function() {
# yaParams.ip = this.responseText;
# }
# xhr.send();
# </script>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter83230288 = new Ya.Metrika({
#                     id:83230288,
#                     params:window.yaParams,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true,
#                     webvisor:true
#                 });
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/83230288" style="position:absolute; left:-9999px;"/></div>
# </noscript></noscript></body>
# </html>

# %%
"""
Upgraded Web Scraper
- Scrapes a URL and saves raw HTML to disk
- Converts HTML to clean Markdown
- Organizes output into a folder structure
- Handles SSL issues (common with .kz domains)
"""

import requests
import urllib3
import re
from pathlib import Path
from datetime import datetime
from urllib.parse import urlparse
from bs4 import BeautifulSoup

# Suppress SSL warnings (for sites with broken certs like kbtu.edu.kz)
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)


# ─── Config ────────────────────────────────────────────────────────────────────

OUTPUT_DIR = Path("scraped_output")  # Base folder for all saved files
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}


# ─── Core Functions ─────────────────────────────────────────────────────────────

def fetch_page(url: str) -> tuple[str, str]:
    """Fetch a page and return (html_content, final_url)."""
    response = requests.get(url, headers=HEADERS, verify=False, timeout=15)
    response.raise_for_status()
    return response.text, response.url


def make_output_folder(url: str) -> Path:
    """Create a unique output folder based on domain + timestamp."""
    domain = urlparse(url).netloc.replace(".", "_") + "_" + urlparse(url).path.replace("/", "_")
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    folder = OUTPUT_DIR / f"{domain}_{timestamp}"
    folder.mkdir(parents=True, exist_ok=True)
    return folder


def save_html(html: str, folder: Path) -> Path:
    """Save raw HTML to disk."""
    path = folder / "page.html"
    path.write_text(html, encoding="utf-8")
    print(f"  [✓] HTML saved → {path}")
    return path


def html_to_markdown(html: str) -> str:
    """Convert HTML content to clean Markdown."""
    soup = BeautifulSoup(html, "html.parser")

    # Remove noise tags
    for tag in soup(["script", "style", "nav", "footer", "head", "noscript", "iframe"]):
        tag.decompose()

    lines = []

    def process(element):
        if isinstance(element, str):
            text = element.strip()
            if text:
                lines.append(text)
            return

        tag = element.name

        if tag in ("h1", "h2", "h3", "h4", "h5", "h6"):
            level = int(tag[1])
            text = element.get_text(separator=" ", strip=True)
            if text:
                lines.append(f"\n{'#' * level} {text}\n")

        elif tag == "p":
            text = element.get_text(separator=" ", strip=True)
            if text:
                lines.append(f"\n{text}\n")

        elif tag in ("ul", "ol"):
            for i, li in enumerate(element.find_all("li", recursive=False), 1):
                text = li.get_text(separator=" ", strip=True)
                bullet = f"{i}." if tag == "ol" else "-"
                if text:
                    lines.append(f"{bullet} {text}")
            lines.append("")

        elif tag == "a":
            href = element.get("href", "")
            text = element.get_text(strip=True)
            if text and href:
                lines.append(f"[{text}]({href})")
            elif text:
                lines.append(text)

        elif tag in ("strong", "b"):
            text = element.get_text(strip=True)
            if text:
                lines.append(f"**{text}**")

        elif tag in ("em", "i"):
            text = element.get_text(strip=True)
            if text:
                lines.append(f"*{text}*")

        elif tag == "blockquote":
            text = element.get_text(separator=" ", strip=True)
            if text:
                lines.append(f"\n> {text}\n")

        elif tag in ("code", "pre"):
            text = element.get_text(strip=True)
            if text:
                lines.append(f"\n```\n{text}\n```\n")

        elif tag == "hr":
            lines.append("\n---\n")

        elif tag == "br":
            lines.append("")

        elif tag == "img":
            alt = element.get("alt", "image")
            src = element.get("src", "")
            if src:
                lines.append(f"![{alt}]({src})")

        elif tag == "table":
            rows = element.find_all("tr")
            for row_idx, row in enumerate(rows):
                cells = row.find_all(["th", "td"])
                row_text = " | ".join(c.get_text(strip=True) for c in cells)
                lines.append(f"| {row_text} |")
                if row_idx == 0:
                    separator = " | ".join(["---"] * len(cells))
                    lines.append(f"| {separator} |")
            lines.append("")

        else:
            for child in element.children:
                process(child)

    body = soup.find("body") or soup
    for child in body.children:
        process(child)

    # Clean up excessive blank lines
    markdown = "\n".join(lines)
    markdown = re.sub(r"\n{3,}", "\n\n", markdown)
    return markdown.strip()


def save_markdown(markdown: str, folder: Path) -> Path:
    """Save Markdown content to disk."""
    path = folder / "page.md"
    path.write_text(markdown, encoding="utf-8")
    print(f"  [✓] Markdown saved → {path}")
    return path


def save_metadata(url: str, soup: BeautifulSoup, folder: Path) -> Path:
    """Save basic page metadata to a text file."""
    title = soup.find("title")
    description = soup.find("meta", attrs={"name": "description"})
    
    meta_lines = [
        f"URL: {url}",
        f"Scraped at: {datetime.now().isoformat()}",
        f"Title: {title.get_text(strip=True) if title else 'N/A'}",
        f"Description: {description['content'] if description and description.get('content') else 'N/A'}",
    ]
    
    path = folder / "metadata.txt"
    path.write_text("\n".join(meta_lines), encoding="utf-8")
    print(f"  [✓] Metadata saved → {path}")
    return path


# ─── Main Scraper ───────────────────────────────────────────────────────────────

def scrape(url: str):
    """Full scraping pipeline: fetch → save HTML → convert to Markdown → save."""
    print(f"\n🔍 Scraping: {url}")
    
    # 1. Fetch
    html, final_url = fetch_page(url)
    soup = BeautifulSoup(html, "html.parser")
    print(f"  [✓] Page fetched ({len(html):,} bytes)")

    # 2. Create output folder
    folder = make_output_folder(final_url)
    print(f"  [✓] Output folder → {folder}")

    # 3. Save raw HTML
    save_html(html, folder)

    # 4. Convert HTML → Markdown and save
    markdown = html_to_markdown(html)
    save_markdown(markdown, folder)

    # 5. Save metadata
    save_metadata(final_url, soup, folder)

    print(f"\n✅ Done! All files saved to: {folder.resolve()}\n")
    return folder


# ─── Run ────────────────────────────────────────────────────────────────────────

urls = [
    "https://kbtu.edu.kz/ru/internatsionalizatsiya/mobilnost-internatsionalizatsiya",
    # Add more URLs here
]

for url in urls:
    try:
        scrape(url)
    except Exception as e:
        print(f"  [✗] Failed to scrape {url}: {e}")
# Out:
# 🔍 Scraping: https://kbtu.edu.kz/ru/internatsionalizatsiya/mobilnost-internatsionalizatsiya
#   [✓] Page fetched (43,449 bytes)
#   [✓] Output folder → scraped_output/kbtu_edu_kz__ru_internatsionalizatsiya_mobilnost-internatsionalizatsiya_20260225_170018
#   [✓] HTML saved → scraped_output/kbtu_edu_kz__ru_internatsionalizatsiya_mobilnost-internatsionalizatsiya_20260225_170018/page.html
#   [✓] Markdown saved → scraped_output/kbtu_edu_kz__ru_internatsionalizatsiya_mobilnost-internatsionalizatsiya_20260225_170018/page.md
#   [✓] Metadata saved → scraped_output/kbtu_edu_kz__ru_internatsionalizatsiya_mobilnost-internatsionalizatsiya_20260225_170018/metadata.txt
#
# ✅ Done! All files saved to: /Users/nurma/vscode_projects/Uni-Agent/research/scraped_output/kbtu_edu_kz__ru_internatsionalizatsiya_mobilnost-internatsionalizatsiya_20260225_170018

# %%
"""
KBTU Site Crawler
- Starts from a seed URL
- Finds all internal links and crawls them recursively (BFS)
- Saves HTML + Markdown + metadata for every page
- Uses your updated folder naming: domain + path + timestamp
- Respects depth limit and max page limit to avoid infinite crawling
- Skips already-visited pages (no duplicates)
"""

import requests
import urllib3
import re
import time
from pathlib import Path
from datetime import datetime
from urllib.parse import urlparse, urljoin, urldefrag
from bs4 import BeautifulSoup
from collections import deque

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)


# ─── Config ────────────────────────────────────────────────────────────────────

SEED_URL       = "https://kbtu.edu.kz/ru/"
ALLOWED_DOMAIN = "kbtu.edu.kz"          # Only follow links on this domain
OUTPUT_DIR     = Path("kbtu_crawl")     # Root output folder
MAX_PAGES      = 10000                    # Safety limit — max pages to crawl
MAX_DEPTH      = 100                      # How deep to follow links (1 = seed only)
DELAY_SECONDS  = 1.0                    # Polite delay between requests (be nice to the server)
HEADERS        = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

# File extensions to skip — these are not HTML pages
SKIP_EXTENSIONS = {
    ".pdf", ".doc", ".docx", ".xls", ".xlsx", ".ppt", ".pptx",
    ".zip", ".rar", ".jpg", ".jpeg", ".png", ".gif", ".svg",
    ".mp4", ".mp3", ".avi", ".css", ".js", ".xml", ".json"
}


# ─── URL Helpers ───────────────────────────────────────────────────────────────

def normalize_url(url: str) -> str:
    """Remove fragments (#section) and trailing slashes for clean deduplication."""
    url, _ = urldefrag(url)
    return url.rstrip("/")


def is_valid_link(url: str) -> bool:
    """Check if a link belongs to the allowed domain and points to an HTML page."""
    parsed = urlparse(url)
    if parsed.scheme not in ("http", "https"):
        return False
    if ALLOWED_DOMAIN not in parsed.netloc:
        return False
    ext = Path(parsed.path).suffix.lower()
    if ext in SKIP_EXTENSIONS:
        return False
    return True


# ─── Folder Naming (your updated version) ─────────────────────────────────────

def make_output_folder(url: str) -> Path:
    """Create a unique output folder based on domain + path + timestamp."""
    parsed = urlparse(url)
    domain = parsed.netloc.replace(".", "_")
    # Clean up path: replace slashes, remove empty segments
    path_part = parsed.path.replace("/", "_").strip("_")
    folder_name = f"{domain}_{path_part}" if path_part else domain
    # Sanitize: remove unsafe characters and collapse underscores
    folder_name = re.sub(r"[^\w\-]", "_", folder_name)
    folder_name = re.sub(r"_+", "_", folder_name).strip("_")
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    folder = OUTPUT_DIR / f"{folder_name}_{timestamp}"
    folder.mkdir(parents=True, exist_ok=True)
    return folder


# ─── Fetching ──────────────────────────────────────────────────────────────────

def fetch_page(url: str) -> str | None:
    """Fetch a URL and return raw HTML, or None on failure."""
    try:
        response = requests.get(url, headers=HEADERS, verify=False, timeout=15)
        response.raise_for_status()
        content_type = response.headers.get("Content-Type", "")
        if "text/html" not in content_type:
            print(f"    [~] Skipped (not HTML): {url}")
            return None
        return response.text
    except Exception as e:
        print(f"    [✗] Failed: {e}")
        return None


def extract_links(html: str, base_url: str) -> list[str]:
    """Pull all valid internal links out of a page."""
    soup = BeautifulSoup(html, "html.parser")
    links = set()
    for tag in soup.find_all("a", href=True):
        href = tag["href"].strip()
        absolute = urljoin(base_url, href)   # Handle relative URLs like /en/about
        normalized = normalize_url(absolute)
        if is_valid_link(normalized):
            links.add(normalized)
    return list(links)


# ─── HTML → Markdown ───────────────────────────────────────────────────────────

def html_to_markdown(html: str) -> str:
    """Convert HTML to clean readable Markdown."""
    soup = BeautifulSoup(html, "html.parser")

    for tag in soup(["script", "style", "nav", "footer", "head", "noscript", "iframe"]):
        tag.decompose()

    lines = []

    def process(element):
        if isinstance(element, str):
            text = element.strip()
            if text:
                lines.append(text)
            return

        tag = element.name
        if tag is None:
            return

        if tag in ("h1", "h2", "h3", "h4", "h5", "h6"):
            level = int(tag[1])
            text = element.get_text(separator=" ", strip=True)
            if text:
                lines.append(f"\n{'#' * level} {text}\n")

        elif tag == "p":
            text = element.get_text(separator=" ", strip=True)
            if text:
                lines.append(f"\n{text}\n")

        elif tag in ("ul", "ol"):
            for i, li in enumerate(element.find_all("li", recursive=False), 1):
                text = li.get_text(separator=" ", strip=True)
                bullet = f"{i}." if tag == "ol" else "-"
                if text:
                    lines.append(f"{bullet} {text}")
            lines.append("")

        elif tag == "a":
            href = element.get("href", "")
            text = element.get_text(strip=True)
            if text and href:
                lines.append(f"[{text}]({href})")
            elif text:
                lines.append(text)

        elif tag in ("strong", "b"):
            text = element.get_text(strip=True)
            if text:
                lines.append(f"**{text}**")

        elif tag in ("em", "i"):
            text = element.get_text(strip=True)
            if text:
                lines.append(f"*{text}*")

        elif tag == "blockquote":
            text = element.get_text(separator=" ", strip=True)
            if text:
                lines.append(f"\n> {text}\n")

        elif tag in ("code", "pre"):
            text = element.get_text(strip=True)
            if text:
                lines.append(f"\n```\n{text}\n```\n")

        elif tag == "hr":
            lines.append("\n---\n")

        elif tag == "img":
            alt = element.get("alt", "image")
            src = element.get("src", "")
            if src:
                lines.append(f"![{alt}]({src})")

        elif tag == "table":
            rows = element.find_all("tr")
            for row_idx, row in enumerate(rows):
                cells = row.find_all(["th", "td"])
                row_text = " | ".join(c.get_text(strip=True) for c in cells)
                lines.append(f"| {row_text} |")
                if row_idx == 0:
                    separator = " | ".join(["---"] * len(cells))
                    lines.append(f"| {separator} |")
            lines.append("")

        else:
            for child in element.children:
                process(child)

    body = soup.find("body") or soup
    for child in body.children:
        process(child)

    markdown = "\n".join(lines)
    markdown = re.sub(r"\n{3,}", "\n\n", markdown)
    return markdown.strip()


# ─── Saving ────────────────────────────────────────────────────────────────────

def save_html(html: str, folder: Path):
    path = folder / "page.html"
    path.write_text(html, encoding="utf-8")
    print(f"    [✓] HTML   → {path}")


def save_markdown(markdown: str, folder: Path):
    path = folder / "page.md"
    path.write_text(markdown, encoding="utf-8")
    print(f"    [✓] MD     → {path}")


def save_metadata(url: str, soup: BeautifulSoup, folder: Path, depth: int):
    title = soup.find("title")
    description = soup.find("meta", attrs={"name": "description"})
    content = "\n".join([
        f"URL:         {url}",
        f"Scraped at:  {datetime.now().isoformat()}",
        f"Depth:       {depth}",
        f"Title:       {title.get_text(strip=True) if title else 'N/A'}",
        f"Description: {description['content'] if description and description.get('content') else 'N/A'}",
    ])
    path = folder / "metadata.txt"
    path.write_text(content, encoding="utf-8")
    print(f"    [✓] Meta   → {path}")


# ─── Crawler (BFS) ─────────────────────────────────────────────────────────────

def crawl():
    """
    BFS crawler — visits pages level by level so shallower pages
    are always scraped before deeper ones.
    Queue items: (url, depth)
    """
    visited    = set()
    queue      = deque([(normalize_url(SEED_URL), 0)])
    pages_done = 0

    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    crawl_log  = OUTPUT_DIR / "crawl_log.txt"
    log_lines  = [
        f"Crawl started : {datetime.now().isoformat()}",
        f"Seed URL      : {SEED_URL}",
        f"Domain filter : {ALLOWED_DOMAIN}",
        f"Max pages     : {MAX_PAGES}",
        f"Max depth     : {MAX_DEPTH}",
        ""
    ]

    print(f"\n🕷️  Starting crawl from : {SEED_URL}")
    print(f"   Domain filter  : {ALLOWED_DOMAIN}")
    print(f"   Max pages      : {MAX_PAGES}")
    print(f"   Max depth      : {MAX_DEPTH}")
    print(f"   Output folder  : {OUTPUT_DIR.resolve()}\n")

    while queue and pages_done < MAX_PAGES:
        url, depth = queue.popleft()

        if url in visited:
            continue
        if depth > MAX_DEPTH:
            continue

        visited.add(url)
        pages_done += 1

        print(f"[{pages_done}/{MAX_PAGES}] depth={depth}  {url}")

        # ── Fetch ──
        html = fetch_page(url)
        if not html:
            log_lines.append(f"FAILED   depth={depth}  {url}")
            continue

        soup = BeautifulSoup(html, "html.parser")

        # ── Save ──
        folder = make_output_folder(url)
        save_html(html, folder)
        save_markdown(html_to_markdown(html), folder)
        save_metadata(url, soup, folder, depth)
        log_lines.append(f"OK       depth={depth}  {url}  →  {folder.name}")

        # ── Enqueue new links ──
        if depth < MAX_DEPTH:
            new_links = extract_links(html, url)
            added = 0
            for link in new_links:
                if link not in visited:
                    queue.append((link, depth + 1))
                    added += 1
            print(f"    [+] Queued {added} new links\n")

        time.sleep(DELAY_SECONDS)

    # ── Final log ──
    log_lines += [
        "",
        f"Crawl finished : {datetime.now().isoformat()}",
        f"Pages scraped  : {pages_done}",
    ]
    crawl_log.write_text("\n".join(log_lines), encoding="utf-8")

    print(f"\n✅ Crawl complete!")
    print(f"   Pages scraped : {pages_done}")
    print(f"   Output folder : {OUTPUT_DIR.resolve()}")
    print(f"   Crawl log     : {crawl_log.resolve()}\n")


# ─── Run ───────────────────────────────────────────────────────────────────────
crawl()
# Out:
# 🕷️  Starting crawl from : https://kbtu.edu.kz/ru/
#    Domain filter  : kbtu.edu.kz
#    Max pages      : 10000
#    Max depth      : 100
#    Output folder  : /Users/nurma/vscode_projects/Uni-Agent/research/kbtu_crawl
#
# [1/10000] depth=0  https://kbtu.edu.kz/ru
#     [✓] HTML   → kbtu_crawl/kbtu_edu_kz_ru_20260225_172457/page.html
#     [✓] MD     → kbtu_crawl/kbtu_edu_kz_ru_20260225_172457/page.md
#     [✓] Meta   → kbtu_crawl/kbtu_edu_kz_ru_20260225_172457/metadata.txt
#     [+] Queued 65 new links
#
# [2/10000] depth=1  https://kbtu.edu.kz/ru/ob-universitete/tsentr-esg-kompetentsij-kbtu
#     [✓] HTML   → kbtu_crawl/kbtu_edu_kz_ru_ob-universitete_tsentr-esg-kompetentsij-kbtu_20260225_172459/page.html
#     [✓] MD     → kbtu_crawl/kbtu_edu_kz_ru_ob-universitete_tsentr-esg-kompetentsij-kbtu_20260225_172459/page.md
#     [✓] Meta   → kbtu_crawl/kbtu_edu_kz_ru_ob-universitete_tsentr-esg-kompetentsij-kbtu_20260225_172459/metadata.txt
#     [+] Queued 47 new links
#
# [3/10000] depth=1  https://kbtu.edu.kz/ru/studentam/student-fee-rus
#     [✓] HTML   → kbtu_crawl/kbtu_edu_kz_ru_studentam_student-fee-rus_20260225_172500/page.html
#     [✓] MD     → kbtu_crawl/kbtu_edu_kz_ru_studentam_student-fee-rus_20260225_172500/page.md
#     [✓] Meta   → kbtu_crawl/kbtu_edu_kz_ru_studentam_student-fee-rus_20260225_172500/metadata.txt
#     [+] Queued 46 new links
#
# [4/10000] depth=1  https://kbtu.edu.kz/ru/activity/5050-vysshee-obrazovanie-i-nauka-god-tsifrovizatsii-i-iskusstvennogo-intellekta
#     [✓] HTML   → kbtu_crawl/kbtu_edu_kz_ru_activity_5050-vysshee-obrazovanie-i-nauka-god-tsifrovizatsii-i-iskusstvennogo-intellekta_20260225_172501/page.html
#     [✓] MD     → kbtu_crawl/kbtu_edu_kz_ru_activity_5050-vysshee-obrazovanie-i-nauka-god-tsifrovizatsii-i-iskusstvennogo-intellekta_20260225_172501/page.md
#     [✓] Meta   → kbtu_crawl/kbtu_edu_kz_ru_activity_5050-vysshee-obrazovanie-i-nauka-god-tsifrovizatsii-i-iskusstvennogo-intellekta_20260225_172501/metadata.txt
#     [+] Queued 47 new links
#
# [5/10000] depth=1  https://kbtu.edu.kz/akademiya-korporativnogo-obrazovaniya
#     [✗] Failed: 404 Client Error: Not Found for url: https://kbtu.edu.kz/kz/akademiya-korporativnogo-obrazovaniya
# [6/10000] depth=1  https://kbtu.edu.kz/ru/studentam/antiterror-rus
#     [✓] HTML   → kbtu_crawl/kbtu_edu_kz_ru_studentam
page.md
#     [✓] Meta   → kbtu_crawl/kbtu_edu_kz_en_news_5028-kbtu-student-receives-a-modern-stair-climbing-wheelchair_20260225_184213/metadata.txt
#     [+] Queued 0 new links
#
# [3865/10000] depth=4  https://kbtu.edu.kz/ru/novosty/4805-v-kbtu-sostoyalsya-the-uk-alumni-meeting
#     [✓] HTML   → kbtu_crawl/kbtu_edu_kz_ru_novosty_4805-v-kbtu-sostoyalsya-the-uk-alumni-meeting_20260225_184214/page.html
#     [✓] MD     → kbtu_crawl/kbtu_edu_kz_ru_novosty_4805-v-kbtu-sostoyalsya-the-uk-alumni-meeting_20260225_184214/page.md
#     [✓] Meta   → kbtu_crawl/kbtu_edu_kz_ru_novosty_4805-v-kbtu-sostoyalsya-the-uk-alumni-meeting_20260225_184214/metadata.txt
#     [+] Queued 2 new links
#
# [3866/10000] depth=4  https://kbtu.edu.kz/ru/novosty/4806-zavershen-i-etap-vnutrivuzovskogo-konkursa-na-prisvoenie-zvaniya-luchshij-prepodavatel-vuza-2024-v-konkurse-prinyali-uchastie-6-kandidatov-iz-kotorykh-5-pretendentov-napravleny-dlya-uchastiya-v-respublikanskom-etape
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/pathlib/_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#
# OSError: [Errno 63] File name too long: 'kbtu_crawl/kbtu_edu_kz_ru_novosty_4806-zavershen-i-etap-vnutrivuzovskogo-konkursa-na-prisvoenie-zvaniya-luchshij-prepodavatel-vuza-2024-v-konkurse-prinyali-uchastie-6-kandidatov-iz-kotorykh-5-pretendentov-napravleny-dlya-uchastiya-v-respublikanskom-etape_20260225_184215'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 326
#     322     print(f"   Crawl log     : {crawl_log.resolve()}\n")
#     325 # ─── Run ───────────────────────────────────────────────────────────────────────
# --> 326 crawl()
#
# Cell In[22], line 293, in crawl()
#     290 soup = BeautifulSoup(html, "html.parser")
#     292 # ── Save ──
# --> 293 folder = make_output_folder(url)
#     294 save_html(html, folder)
#     295 save_markdown(html_to_markdown(html), folder)
#
# Cell In[22], line 77, in make_output_folder(url)
#      75 timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
#      76 folder = OUTPUT_DIR / f"{folder_name}_{timestamp}"
# ---> 77 folder.mkdir(parents=True, exist_ok=True)
#      78 return folder
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/pathlib/_local.py:731, in Path.mkdir(self, mode, parents, exist_ok)
#     727     self.mkdir(mode, parents=False, exist_ok=exist_ok)
#     728 except OSError:
#     729     # Cannot rely on checking for EEXIST, since the operating system
#     730     # could give priority to other errors like EACCES or EROFS
# --> 731     if not exist_ok or not self.is_dir():
#     732         raise
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/pathlib/_abc.py:465, in PathBase.is_dir(self, follow_symlinks)
#     461 """
#     462 Whether this path is a directory.
#     463 """
#     464 try:
# --> 465     return S_ISDIR(self.stat(follow_symlinks=follow_symlinks).st_mode)
#     466 except OSError as e:
#     467     if not _ignore_error(e):
#
# File ~/.local/share/uv/python/cpython-3.13.5-macos-aarch64-none/lib/python3.13/pathlib/_local.py:515, in Path.stat(self, follow_symlinks)
#     510 def stat(self, *, follow_symlinks=True):
#     511     """
#     512     Return the result of the stat() system call on this path, like
#     513     os.stat() does.
#     514     """
# --> 515     return os.stat(self, follow_symlinks=follow_symlinks)
#
# OSError: [Errno 63] File name too long: 'kbtu_crawl/kbtu_edu_kz_ru_novosty_4806-zavershen-i-etap-vnutrivuzovskogo-konkursa-na-prisvoenie-zvaniya-luchshij-prepodavatel-vuza-2024-v-konkurse-prinyali-uchastie-6-kandidatov-iz-kotorykh-5-pretendentov-napravleny-dlya-uchastiya-v-respublikanskom-etape_20260225_184215'
